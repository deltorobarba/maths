# %% [markdown]
# <a href="https://colab.research.google.com/github/deltorobarba/science/blob/main/maths.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color="blue">**Mathematics 🪼**

# %% [markdown]
# ![science](https://raw.githubusercontent.com/deltorobarba/science/main/nature.JPG)

# %% [markdown]
# ###### <font color="blue">*Heisenberg-Weyl*

# %% [markdown]
# <font color="blue">**Heisenberg-Weyl Algebra**
#
# 1. Hamiltonian: $\hat{H} \propto \hat{P}^2 + \hat{Q}^2$  $ = \hbar \omega \left(\hat{a}^\dagger \hat{a} + \frac{1}{2}\right) = \hbar \omega (\hat{n} + \frac{1}{2})$. $\hat{H}$ is generator of basis state rotations in phase space ($Q / P$)
#   * Ladder Operator Form: $\hat{H}=\hbar \omega\left(a^{\dagger} a+\frac{1}{2}\right)$. $\hat{a}$ and $\hat{a}^\dagger$ (Ladder Operators):  jump Up and Down the energy ladder.  Operators $\hat{Q}$ and $\hat{P}$ linear combinations of $\hat{a}, \hat{a}^\dagger$. Their sum of squares ($\hat{Q}^2 + \hat{P}^2$) gives Number Operator $\hat{n}$ for total energy.
#   * Position/Momentum Form $\hat{H}=\frac{p^2}{2 m}+\frac{1}{2} m \omega^2 x^2$. [Quantum Harmonic Oscillation](https://en.wikipedia.org/wiki/Quantum_harmonic_oscillator) describes physical swap Kinetic $\leftrightarrow$ Potential = Time Evolution. Eg $t=0$: state in Position $Q$. Time evolution by $t=\frac{\pi}{2\omega}$ rotated $90^\circ$ to Momentum $P$ $\rightarrow$ is QFT!
#   * Everything in quantum physics can be mapped onto a ['Phase Space'](https://en.wikipedia.org/wiki/Phase_space) of position $Q$ and momentum $P$ ([Formulation](https://en.wikipedia.org/wiki/Phase-space_formulation))
#   * Mathematically, in QM Time is an Angle. In the expression $e^{-i\theta}$, $\theta$ must be a dimensionless number (an angle in radians). When we write the time-evolution operator as $\hat{U}(t) = e^{-i \hat{H} t / \hbar}$, the quantity $(\hat{H} t / \hbar)$ plays the role of that angle. In QM, states don't move along a trajectory like a baseball but its complex phase rotates. **If a system is in an energy eigenstate (Stationary State) with energy $E$, it stays in that state, but its phase "spins" at a frequency of $\omega = E/\hbar$.**
#
# 2. Unit Circle (Why Complex Numbers?)
#   * [Harmonic oscillator](https://en.wikipedia.org/wiki/Simple_harmonic_motion) moves back and forth: $x(t) = \cos(\omega t)$, described by real numbers: Position ($x$) and Velocity ($v$). Can combined to complex amplitude: $\alpha = x + i p$. Rotation keeps structure (unitary), rotates without changing magnitude (length).
#   * Annihilation operator $\hat{a}$ combines Position and Momentum into single complex number: $\hat{a} \propto \hat{Q} + i\hat{P}$. This is $x + iy$ (Euler) $\rightarrow$ Real Axis (Position) $\cos(\omega t)$. Imaginary Axis (Momentum) $i\sin(\omega t)$. Rotation (Time) $e^{i\omega t}$ = Oscillation between $Q$ and $P$
#   * Multiplying $\hat{a}$ by $e^{-i\omega t}$ rotates the vector in the complex plane. When the vector is horizontal (Real), the particle has maximum Position $Q$. When the vector is vertical (Imaginary), the particle has maximum Momentum $P$. **90° switch from X to Z = QFT.**
#
# 3. Exponentiation: Raise $e$ to power of position and momentum with $e^{-i \hat{G} \theta}$ to get from QHO to Quantum Operators
#   * $\hat{U} = e^{-i \hat{G} \theta}$ unitary is general form that describes movement of state in terms of fundamental operators $\hat{Q}$ and $\hat{P}$.
#     * $e^{i \theta}$ represents point on unit circle and keeps it unitary ($U^{\dagger}U=I$).
#     * $-i$ ensures transformation is rotation in Hilbert space that preserves length (norm) of state vector.
#     * $\hat{G}$ is a transformation. Parameter $\theta$ scales transformation.
#   * **Exponentiation** allows us to describe different transformations (gates). We just construct generator $\hat{G}$ with linear or non-linear combinations of fundamental operators $\hat{Q}$ + $\hat{P}$ (or $\hat{a}$ and $\hat{a}^\dagger$) or $\hat{X}$ and $\hat{Z}$ (modulo 𝑑) for qudit/qubit from Heisenberg-Weyl group. Exponentiation of unitary $\hat{U} = e^{-i \hat{H} t / \hbar}$ is defined and computed upon $[\hat{x}, \hat{p}] = i\hbar$ (CCR).
#     * If $\hat{G}$ is energy $\hat{H}$ (Hamiltonian), then $\hat{U} = e^{-i \hat{H} t / \hbar}$ where $\theta$ is duration of time $\frac{t}{\hbar}$ because because $\hat{H}$ is Time Evolution
#   * **Linear Transformations**: Generated by linear or quadratic functions ($\le 2^{\text{nd}}$ degree) of fundamental operators $\hat{Q}, \hat{P}$, or $\hat{X}$ and $\hat{Z}$ (modulo 𝑑). Not orthogonal and form overcomplete basis. Eigenstates of annihilation operator $\hat{a}$.
#   * **Non-Linear Transformations**: Generated by cubic or higher functions ($\ge 3^{\text{rd}}$ degree) of fundamental operators $\hat{Q}, \hat{P}$, or $\hat{X}$ and $\hat{Z}$ (modulo 𝑑). Break symmetry. Form orthonormal basis. Eigenstates of number operator $\hat{n} = \hat{a}^\dagger \hat{a}$.
#
# 4. Conjugate relation: An operator is a Generator of its conjugate variable's translation: This allows basis change $X$ <> $P$
#   * **Clock Z** *represents* Position (Potential) but *generates* Momentum Translation (Kick) - $D_{0,p} \sim Z^p$ applied (moves faster)
#   * **Shift X** *represents* Momentum (Kinetic) but *generates* Position Translation (Slide) - $D_{q,0} \sim X^q$ applied (new position)
#   * Connected via **Fourier Transform**. Used in $D_{q,p} = \tau^{qp} X^q Z^p$.  Based on commutation relation: $[x̂, p̂] = i ħ$ (for continuous), $ZX = \omega XZ$ (Weyl relation). For example in: Characteristic ($\chi(\xi)$) <> Wigner function.
#
# 5. Kinetic Energy $\hat{P}^2$ $\rightarrow$ Momentum $\hat{P} = \frac{i}{\sqrt{2}}(\hat{a}^\dagger - \hat{a})$ $\rightarrow$ Shift operator $X = e^{-i \hat{P} \delta}$ $\rightarrow$ Bit Flip/Pauli $X$. Generator linear in $\hat{P}$
#   * **Kinetic Energy $\hat{P}^2$** corresponds to hopping term/Laplacian $\approx (X + X^\dagger)$. (Real/Symmetric) > used in Google's OTOC.
#   * **Gaussian: Momentum** $\hat{P} = \frac{i}{\sqrt{2}}(\hat{a}^\dagger - \hat{a})$ $\rightarrow$ corresponds to derivative $\approx i(X^\dagger - X)$. (Complex/Imaginary, anti-symmetric)
#   * **Clifford (Qudit): Shift**  $\hat{X}^a |j\rangle = |j+1\rangle \pmod d\rangle$. |0⟩→|1⟩→|2⟩→|d−1⟩→|0⟩. Eigenvalues of $X$ are powers of $\omega$ (via Fourier). Because:  In "Momentum Basis", Shift operator is diagonal! Looks like Clock matrix. Because $X = \text{DFT}^\dagger \cdot Z \cdot \text{DFT}$.
#   * **Clifford (Qubit): Pauli X**: $\sigma_x |j\rangle = |j+1 \pmod 2\rangle$. Swaps 0<>1. $ZX = -XZ$. Phase is ω = $e^{i 2\pi/2}$ = -1, Eigenvalues 1, -1.
#   * **Conjugation relation: Shift $X$ *represents* Momentum (Kinetic) but *generates* Position Shift** - $D_{q,0} \sim X^q$ applied (new position). Matrix $X$ is Real and Off-Diagonal (Permutation matrix of 0s and 1s). Shift is exponentiated momentum $X \approx e^{-i \hat{P} \delta_x}$
#
# 6. Potential Energy $\hat{Q}^2$ $\rightarrow$ Position $\hat{Q} = \frac{1}{\sqrt{2}}(\hat{a} + \hat{a}^\dagger)$ $\rightarrow$ Clock operator $Z = e^{i \hat{Q} \delta}$ $\rightarrow$ Phase Flip/Pauli-$Z$. Generator linear in $\hat{Q}$
#   * **Gaussian: Position** $\hat{Q} = \frac{1}{\sqrt{2}}(\hat{a} + \hat{a}^\dagger)$ is observable. Position ($\hat{Q}$) observable has Real eigenvalues (location index $k$).
#   * **Clifford (Qudit): Clock** $\hat{Z}^b$ acts as $|k\rangle \rightarrow \omega^k |k\rangle$ where $\omega=e^{2\pi i/d}$ phase gradient + primitive $d$-th root unity (=Eigenvalues). $e^{ix}$ is clock phase gate $Z$ with complex eigenvalues on unit circle (phases $\omega^k$ on unit circle). Raised to $d$-th power ($\omega^0, \omega^1, \dots, \omega^{d-1}$) to generate $d$ solutions to tag each basis state k. For $d=3$, $\omega = e^{i 2\pi/3}$  (unitary but not Hermitian).
#   * **Clifford (Qubit): Phase Flip/Pauli $Z$**. $d=2$ primitive root of unity: $\omega_2 = e^{2\pi i / 2} = e^{i\pi} = -1$ $→$  $\sigma_z |j\rangle = (-1)^j |j\rangle = \omega^j |j\rangle$. This is mod 2 version: $ZX = -XZ (ω = -1)$. Adds a $-1$ phase to $\sigma_z |1\rangle = -|1\rangle$, but leaves $\sigma_z |0\rangle = |0\rangle$. = Pauli $Z$ matrix is both Unitary (preserves probabilities) and Hermitian (is its own conjugate). We can observe it directly.
#   * **Conjugation relation: Clock $Z$ *represents* Position (Potential) but *generates* Momentum (Kick)** - $D_{0,p} \sim Z^p$ applied (move faster). Matrix $Z$ complex Eigenvalues (phases on unit circle) and diagonal. Operator $\hat{Q}$ has real eigenvalues (location)
#
# 7. [Hamiltonian Operator](https://en.wikipedia.org/wiki/Hamiltonian_(quantum_mechanics)#Schr%C3%B6dinger_equation) generates [Time Evolution](https://en.wikipedia.org/wiki/Time_evolution) / Rotation / Basis Change. Generator is Quadratic $H = \hat{P}^2 + \hat{Q}^2$
#   * **Gaussian: Phase Shifter** $R(θ)=e^{-i \theta \hat{n}}$ rotates state by angle $θ$. For $θ=π/2$ (quarter turn), 90° = Fourier Transform. Generating operator is number operator $\hat{n}$ with Hamiltonian $H \propto \hat{Q}^2 + \hat{P}^2$ with rotation operator $R(θ)=e^{-i \theta (Q^2 + P^2)}$. $\hat{Q}$-$\hat{P}$ swap represents how potential and kinetic energy switch back and forth forever = basis change (rotation)
#   * **Clifford (Qudit): Quantum Fourier Transform (QFT)** is exactly Quarter period $\theta = \pi/2$ to rotate $Z$-eigenbasis (Position) into $X$-eigenbasis (Momentum) due to conjugate relation. Basis change by action on computational states $\text{QFT}*d |j \rangle$ =  ${0}^{d-1}  \omega^{jk} |k \rangle$. Basis change: maps single, localized basis state $|j\rangle$ into uniform superposition of all basis states tagged with phase $\omega^{jk}$. $W X W^\dagger = Z$. QFT turns Shift into Clock $\rightarrow$ QFT diagonalizes Shift $X$ operator. $W Z W^\dagger = X^\dagger$. Inverse QFT turns Clock into inverse Shift $\rightarrow$ Qudit $Z$ operator applies phase $\omega^j = e^{2\pi i j / d}$ based on *single* qudit index $j$.
#   * **Clifford (Qubit): Hadamard ($\hat{H}$)**. Conjugate relation allows basis change $Z$<>$X$  via equal superposition $H|0\rangle = |+\rangle$.
#   * Quadratic Generators $\hat{Q}^2 + \hat{P}^2$ geometrically generate rotations around origin of phase space. If you let a state evolve under this generator for a specific "time" or "angle," it's Quantum Fourier Transform. And angle is time in this setting!
#
# 8. [Displacement Operator](https://en.wikipedia.org/wiki/Displacement_operator) generates displacements in Phase Space. Generator is linear $G = q\hat{P} - p\hat{Q}$
#   * **Gaussian: Displacement** $\hat{D}(q, p) = e^{( -\frac{i}{\hbar} (q\hat{P} - p\hat{Q})}$ with generator $H  \propto (q\hat{P} - p\hat{Q})$. Where $H \propto \hat{P} \rightarrow$ generates shift in $Q$. And $H \propto \hat{Q} \rightarrow$ generates shift in $P$. Here called: position / momentum.
#   * **Clifford (Qudit): Displacement** $D_{q,p} = e^{i\pi qp/d} X^q Z^p$. Via Heisenberg-Weyl with of all combinations of shifts and clock/ phases ($X^q Z^p$). Phase factor $e^{i\pi qp/d}$ required because $X$ and $Z$ do not commute (Aharonov-Bohm effect in phase space).
#   * Linear Generators $q\hat{P} - p\hat{Q}$  geometrically don't rotate state around origin but slide to new location (q,p) in phase space
#
# 9. Special Quantum Operators
# * <font color="blue">*Special: Gaussian: Pauli-Y*</font>
#   * is just a product, not independent operator! In qubit $\sigma_y = i \sigma_x \sigma_z$ is just combination of bit and phase flip. For qudits: family of Generalized Pauli Operators defined by product of shifts and clocks: $P_{q,p} = X^q Z^p$.
#   * **For $d=2$ (Qubits):** $X^1 Z^0 = X$ and $X^0 Z^1 = Z$ and $X^1 Z^1 \propto Y$ ($Y$ is just $(1,1)$ point on the grid).
#   * **For $d=3$ (Qutrits):** $X Z$, $X Z^2$, $X^2 Z$, etc. None of these is uniquely called "$Y$". "Pauli $Y$" doesn't vanish; it just becomes one of the many $D_{q,p}$ displacement operators ($q \neq 0, p \neq 0$)
# * <font color="blue">*Special: Shear/Phase Gate*</font>
#   * Gaussian: **Quadratic Phase (Shear)**: Generator $H \propto \hat{Q}^2$. Hamiltonian $H \propto \hat{Q}^2$ (a "Kerr" nonlinearity or a Shear) preserves Position $Q$ but shears Momentum $P \to P + Q$.
#   * Clifford (Qubit): **Phase Gate ($\hat{S}$ or $\hat{P}$)**. $Z \to Z$, $X \to Y \sim XZ$. Phase gate is diagonal. $S = \text{diag}(1, i, \dots)$. It adds a quadratic phase $k^2$ to the wavefunction.
# * <font color="blue">*Special: Entanglement*</font>
#   * **Gaussian: Squeezer + Beam Splitter = Entanglement** $\approx$ CNOT.  Squeeze state to ellipse, then rotate ellipse 45° via Beam Splitter $\rightarrow$ noise becomes correlated between two axes = this is Entanglement. **Squeezer** is $\hat{S}(r) = e^{\left( -\frac{i r}{2\hbar} (\hat{Q}^2 - \hat{P}^2)\right)}$ with generator $H \propto (\hat{Q}^2 - \hat{P}^2)$ $= \hat{Q}\hat{P} + \hat{P}\hat{Q}$. Scales axes: stretches $Q$ and shrinks $P$ (or vice versa). Multiplies position by $e^{-r}$ and momentum by $e^r$. **Beam Splitter** $\hat{B}(\theta) = e^{-i \theta (\hat{Q}_1 \hat{P}_2 - \hat{Q}_2 \hat{P}_1)}$ with generator $H \propto \hat{Q}_1\hat{P}_2 - \hat{Q}_2\hat{P}_1$. This is the angular momentum operator in phase space. It performs passive rotation between two modes.If $\theta = \pi/4$ (50:50 Beam Splitter), it mixes the two inputs equally:$\hat{a}_1 \to \frac{\hat{a}_1 + \hat{a}_2}{\sqrt{2}}$ and $\hat{a}_2 \to \frac{\hat{a}_1 - \hat{a}_2}{\sqrt{2}}$.
#   * **Clifford (Qudit): C-SUM ($CX$)** $|c\rangle|t\rangle \to |c\rangle|t \oplus c\rangle  \pmod d\rangle$.  Adds control bit to target bit modulo d. $\hat{C}_{\text{SUM}} = e^{-i \hat{Q}_1 \hat{P}_2}$ with generator $\hat{Q}_1 \hat{P}_2$. Couples Position particle 1 to Momentum (shift) particle 2. C-SUM gate built via: Beam Splitter + Squeezing + Inverse Beam Splitter
#   * **Clifford (Qubit): CNOT**. $|c\rangle|t\rangle \to |c\rangle|t \oplus c\rangle  \pmod 2\rangle$. Adds control bit to target bit modulo 2.
# * <font color="blue">*Special: Cubic Phase*</font>
#   * **Non-Gaussian: Cubic Phase** $\hat{U} = e^{i\gamma \hat{Q}^3}$ with generator $H \propto \hat{Q}^3$.  Cubic Phase gate $V(\gamma) = e^{i \gamma \hat{Q}^3}$ distorts phase space. A circle (coherent state) becomes a "banana" shape with negative Wigner function regions—the signature of non-classicality.
#   * **Non-Clifford (Qudit): Discrete Cubic Phase ($\hat{T}_d$)** (mod d). Generalized Magic Gates, often diagonal phases like $e^{i \frac{2\pi}{d^3} k^3}$. Corresponds to degree-3 polynomial phases: $T_d |k\rangle = \omega^{k^3} |k\rangle$. Exactly analogous to the cubic phase gate: $V(\gamma) = e^{i\gamma \hat{x}^3}$.
#   * **Non-Clifford (QUBIT): $\hat{T}$-gate** (magic gate) degree-3 (or $\pi/8$ gate): $\hat{T} = e^{-i \pi/8 \hat{Z}}$ - is cubic phase in discrete phase space (mod 2) : $\pi/8$ phase. The Clifford group maps Pauli operators to Pauli operators (Level 2).
# * <font color="blue">*Special: Other Operators*</font>
#   * **Non-Gaussian: Kerr** $\hat{U} = e^{i\chi \hat{n}^2}$ where $\hat{n} = \hat{a}^\dagger \hat{a}$. Generator $\propto (\hat{Q}^2 + \hat{P}^2)^2$ (quartic). Since $\hat{n} \sim Q^2 + P^2$, then $\hat{n}^2 \sim (Q^2 + P^2)^2 \sim Q^4 + \dots$This is a Quartic (4th order) potential. This represents a medium where the refractive index changes based on intensity. In computation, it is often used to build "Cat States" (macroscopic superpositions), which are excellent candidates for error-corrected logical qubits (Bosonic Codes).
#   * **Non-Clifford (Qudit): General high-order phase gates**
#   * **Non-Clifford (QUBIT): Toffoli Gate** (also Non-Clifford and Universal with $\hat{H}$ and $\hat{T}$)

# %% [markdown]
# ###### <font color="blue">*Exponentiation*

# %% [markdown]
# <font color="blue">**Exponentiation**:
#
# * [Video](https://www.youtube.com/watch?v=9CBS5CAynBE$0)
#
# 1. Intuitive Texterklärung: Exponentiation als universeller Übersetzer
#
# Die Exponentiation ist die fundamentale Brücke zwischen dem Infinitesimalen und dem Globalen. In der Mathematik stoßen wir oft auf gekrümmte, multiplikative Räume (Lie-Gruppen oder die Mannigfaltigkeit der Quantenzustände), die global schwer zu greifen sind. Lokal betrachtet besitzen sie jedoch einen flachen, linearen Tangentialraum (die Lie-Algebra), in dem wir Vektoren einfach addieren können.
# Die Exponentialabbildung nimmt eine solche flache, infinitesimale Anweisung – einen sogenannten **Generator** – und integriert sie entlang eines kontinuierlichen Flusses zu einer makroskopischen, endlichen Transformation. In der Quantenmechanik bekommt dies eine tief physikalische Bedeutung: Die Exponentiation wird zum Motor der Zeit, der einen abstrakten algebraischen Operator (den Symmetrie-Generator) in eine reale physikalische Bewegung oder Transformation (einen unitären Operator) verwandelt.
#
# 2. Formale Definition & Formeln
#
# **A. Die abstrakte Exponentialabbildung (Lie-Theorie)**
# Sei $G$ eine Lie-Gruppe und $\mathfrak{g}$ ihre zugehörige Lie-Algebra, ausgestattet mit der Lie-Klammer $[\cdot, \cdot]$. Die Exponentialabbildung ist ein Morphismus von der linearen Algebra in die Lie-Gruppe:
#
#
# $$\exp: \mathfrak{g} \to G$$
#
#
# Für Matrix-Lie-Algebren ist dies die formale Potenzreihe:
#
#
# $$\exp(X) = \sum_{k=0}^{\infty} \frac{X^k}{k!} = I + X + \frac{X^2}{2} + \frac{X^3}{6} + \dots$$
#
#
# Die Struktur der Multiplikation im gekrümmten Raum $G$ wird dabei vollständig durch die Kommutatoren im flachen Raum $\mathfrak{g}$ diktiert, was durch die **Baker-Campbell-Hausdorff-Formel** formalisiert wird:
#
#
# $$\exp(X)\exp(Y) = \exp\left(X + Y + \frac{1}{2}[X,Y] + \dots\right)$$
#
# **B. Unitarität und Dynamik in der Quantenmechanik**
# In der Quantenmechanik werden Transformationen durch die Exponentiation hermitescher Operatoren (Generatoren) $\hat{G}$ erzeugt. Multipliziert mit der imaginären Einheit $-i$, garantiert die Exponentiation, dass der resultierende Operator $\hat{U}$ unitär ist ($\hat{U}^\dagger \hat{U} = I$) und somit Wahrscheinlichkeiten erhält. Für einen Parameter $\theta$ (z.B. Zeit oder Abstand) lautet die Transformation:
#
#
# $$\hat{U}(\theta) = \exp\left(-i \theta \hat{G}\right)$$
#
#
# Ist $\hat{G} = \hat{H}$ der Hamiltonoperator und $\theta = t$ die Zeit, erhalten wir exakt die formale Lösung der Schrödingergleichung: $|\psi(t)\rangle = \exp(-i\hat{H}t) |\psi(0)\rangle$.
#
# 3. Konkrete Beispiele: Von Lie-Algebren zur Quantendynamik
#
# **Beispiel A: Diskreter Raum – Pauli-Matrizen und Qubit-Rotationen (SU(2))**
# Die spezielle unitäre Gruppe $SU(2)$ beschreibt verlustfreie Operationen auf einem Qubit. Ihre Lie-Algebra $\mathfrak{su}(2)$ wird durch die Pauli-Matrizen aufgespannt. Nehmen wir den Generator $\hat{X}$ (Pauli-X-Matrix). Da $\hat{X}^2 = I$, kollabiert die unendliche Taylor-Reihe auf wundersame Weise zu einer Matrix-Version der Euler-Formel. Die makroskopische Rotation um den Winkel $\theta$ ist:
#
#
# $$R_x(\theta) = \exp\left(-i \frac{\theta}{2} \hat{X}\right) = \cos\left(\frac{\theta}{2}\right) I - i \sin\left(\frac{\theta}{2}\right) \hat{X}$$
#
# **Beispiel B: Kontinuierlicher Phasenraum – Lineare Generatoren (Translation)**
# Im unendlich-dimensionalen Phasenraum bilden die nicht-kommutierenden Operatoren für Ort $\hat{Q}$ und Impuls $\hat{P}$ (mit $[\hat{Q}, \hat{P}] = i\hbar$) die Basis der Lie-Algebra. Ein linearer Generator in $\hat{P}$ erzeugt eine reine Verschiebung (Translation) des Ortes. Der makroskopische Shift-Operator $\hat{X}(a)$ für eine Strecke $a$ lautet:
#
#
# $$\hat{X}(a) = \exp\left(-i a \hat{P}\right)$$
#
#
# Wenden wir dies auf einen Ortseigenzustand $|x\rangle$ an, schiebt der Operator das System exakt um $a$ weiter:
#
#
# $$\hat{X}(a)|x\rangle = |x+a\rangle$$
#
# **Beispiel C: Kontinuierlicher Phasenraum – Quadratische Generatoren (Rotation & Fourier)**
# Wenn wir zu quadratischen Generatoren übergehen, etwa dem Hamiltonoperator des harmonischen Oszillators $\hat{H} \propto \hat{Q}^2 + \hat{P}^2$, erzeugen wir keine Translationen mehr, sondern *Rotationen* im Phasenraum.
# Exponentieren wir diesen Generator für exakt eine Vierteldrehung ($\theta = \pi/2$), so vertauschen sich die Rollen von Ort und Impuls. Diese globale mathematische Operation ist kategorientheoretisch und analytisch nichts anderes als die kontinuierliche **Quanten-Fourier-Transformation**:
#
#
# $$\mathcal{F} = \exp\left(-i \frac{\pi}{2} (\hat{Q}^2 + \hat{P}^2)\right)$$
#
#
# Durch diese Exponentiation wird aus der summierten quadratischen Lie-Algebra-Struktur das globale Integral der Fourier-Transformation!
#
# 1. Die eine Idee dahinter
#
# Wenn ich die Essenz auf einen Satz verdichten müsste:
#
# > **Exponentiation ist die Brücke zwischen Addition und Multiplikation — und damit zwischen *infinitesimaler* und *endlicher* Struktur.**
#
# Alles Besondere an $\exp$ ist ein Echo dieses einen Prinzips. Auf der einen Seite lebt eine *additive* Welt (Vektorräume, Lie-Algebren, Erzeuger, Dinge, die man linear überlagert), auf der anderen eine *multiplikative* Welt (Gruppen, Transformationen, Symmetrien, Dinge, die man hintereinanderschaltet). Die Exponentialabbildung übersetzt die eine in die andere. Dein Quanten-Stichwort „Erzeuger $\hat G$ $\to$ Gate $\hat U = e^{-i\hat G\theta}$" ist exakt diese Übersetzung in Aktion.
#
# 2. Die definierenden Eigenschaften (formal)
#
# Drei Eigenschaften charakterisieren $\exp$ — und je nach Blickwinkel erscheint mal die eine, mal die andere als „die wesentliche".
#
# **(a) Homomorphismus-Eigenschaft (die Seele).** $\exp$ ist der (bis auf Skalierung) eindeutige stetige Gruppenhomomorphismus
# $$\exp:\;(\mathbb{R},+)\;\longrightarrow\;(\mathbb{R}_{>0},\,\cdot\,),\qquad e^{x+y}=e^x\,e^y.$$
# Genauer: Erfüllt eine stetige Funktion die *Funktionalgleichung* $f(x+y)=f(x)f(y)$, so gilt zwingend $f(x)=e^{cx}$. Die gesamte algebraische Struktur von $\exp$ steckt schon in dieser Gleichung.
#
# **(b) Eigenfunktion der Ableitung.** $\exp$ ist die eindeutige Lösung von
# $$\frac{d}{dx}f = f,\qquad f(0)=1.$$
# $e^x$ ist der *Fixpunkt* des Ableitungsoperators (zum Eigenwert $1$). Das ist der Grund, warum unter allen Basen ausgerechnet $e$ die „natürliche" ist: $\frac{d}{dx}a^x = (\ln a)\,a^x$, und nur bei $a=e$ verschwindet der Störfaktor.
#
# **(c) Reihendarstellung.** $\displaystyle e^x=\sum_{n=0}^\infty \frac{x^n}{n!}$. Diese Formel ist der Schlüssel zur Verallgemeinerung, denn sie braucht *nur* Addition, Multiplikation und einen Grenzwert — also funktioniert sie für **jedes** Objekt, in dem man Potenzen bilden und summieren kann: Matrizen, beschränkte Operatoren, Elemente einer Banach-Algebra.
#
# 3. Die Operator-/Lie-Sicht — der Kern deiner Notizen
#
# Hier wird es richtig schön, weil deine Heisenberg-Weyl-Notizen genau das Lie-theoretische Bild zeichnen. Setzt man in $(c)$ eine Matrix bzw. einen Operator $A$ ein, entsteht
# $$e^{tA}=\sum_{n=0}^\infty \frac{t^n A^n}{n!},\qquad \frac{d}{dt}e^{tA}=A\,e^{tA},\quad e^{0\cdot A}=I.$$
# $t\mapsto e^{tA}$ ist die **Einparametergruppe** (der „Fluss"), die von $A$ *erzeugt* wird. Damit ist die Exponentialabbildung der Lie-Theorie
# $$\exp:\;\mathfrak{g}\;\longrightarrow\;G$$
# geboren: Sie schickt die Lie-Algebra $\mathfrak g$ (Tangentialraum am Einselement — ein *linearer*, additiver Raum) in die Lie-Gruppe $G$ (eine *multiplikative* Mannigfaltigkeit). Erzeuger werden zu Symmetrien.
#
# Deine Notiz $\hat U = e^{-i\hat G\theta}$ ist genau das. Und das rigorose Fundament dahinter ist der **Satz von Stone**: Jede stark-stetige Einparametergruppe unitärer Operatoren $\hat U_t$ hat die Form
# $$\hat U_t = e^{-it\hat H/\hbar}$$
# für einen eindeutigen selbstadjungierten (i. A. unbeschränkten) Erzeuger $\hat H$ — und umgekehrt. Das ist die präzise Aussage hinter „der Hamiltonian erzeugt Zeitentwicklung". Die Bijektion *Erzeuger $\leftrightarrow$ Transformation* ist nichts anderes als die Brücke aus §1, jetzt im Hilbertraum.
#
# **Konkretes Beispiel aus deinen Notizen** ($X = e^{-i\hat P\delta}$). Für den Shift-Erzeuger ist $e^{-i\hat P\delta}$ ein Translationsoperator. Heuristisch im kontinuierlichen Fall:
# $$\bigl(e^{-i\delta \hat P}\psi\bigr)(x)=e^{-\delta \frac{d}{dx}}\psi(x)=\sum_n \frac{(-\delta)^n}{n!}\psi^{(n)}(x)=\psi(x-\delta).$$
# Die Taylor-Reihe *ist* die Verschiebung — der Impulsoperator $\hat P$ erzeugt Ortstranslation. Genau das meint deine „Conjugate relation". Und die Nicht-Kommutativität $[\hat x,\hat p]=i\hbar$ ist der Grund, warum man $e^{A+B}\neq e^A e^B$ hat und die Baker-Campbell-Hausdorff-Korrektur (dein Phasenfaktor $e^{i\pi qp/d}$ bei $D_{q,p}$) braucht.
#
# 4. Die kategorientheoretische Sicht
#
# Jetzt der Perspektivwechsel, nach dem du gefragt hast — und der erklärt, *warum es überhaupt „Exponentiation" heißt*. Die Wurzel ist kombinatorisch:
#
# > **$b^a$ = Anzahl der Abbildungen von einer $a$-elementigen in eine $b$-elementige Menge.**
#
# In **Set** definiert man das **Exponentialobjekt** $B^A$ als die Menge aller Funktionen $A\to B$. Für endliche Mengen gilt $|B^A| = |B|^{|A|}$ — die Notation ist also kein Zufall, sondern *Definition*. Exponentiation zählt Morphismen.
#
# Die strukturelle Charakterisierung ist eine **Adjunktion**. Ein Exponentialobjekt $B^A$ ist durch die natürliche Bijektion
# $$\operatorname{Hom}(C\times A,\;B)\;\cong\;\operatorname{Hom}(C,\;B^A)$$
# festgelegt — d. h. $(-\times A)\dashv (-)^A$, der Exponentialfunktor ist rechtsadjungiert zum Produktfunktor. Eine Kategorie mit allen endlichen Produkten und Exponentialen heißt **kartesisch abgeschlossen** (CCC). Die Adjunktion ist genau das **Currying**: „eine Funktion von zwei Argumenten" $=$ „eine Funktion, die eine Funktion zurückgibt".
#
# Das Eleganteste: **Die Rechenregeln der Potenzen sind Schatten universeller Eigenschaften.** Sie folgen rein formal aus Produkt-, Koprodukt- und Adjunktionsstruktur:
#
# | Kategoriell (natürlicher Iso) | Arithmetisch |
# |---|---|
# | $B^{A+C}\cong B^A\times B^C$ | $b^{a+c}=b^a\,b^c$ |
# | $(B\times C)^A\cong B^A\times C^A$ | $(bc)^a=b^a c^a$ |
# | $(B^A)^C\cong B^{A\times C}$ | $(b^a)^c=b^{ac}$ |
# | $B^1\cong B,\quad B^0\cong 1$ | $b^1=b,\quad b^0=1$ |
#
# Beachte, dass die erste Zeile — Exponential eines *Koprodukts* wird zum *Produkt* der Exponentiale — die kategorielle Inkarnation der Homomorphismus-Eigenschaft $e^{x+y}=e^xe^y$ aus §2(a) ist! Und die dritte Zeile *ist* das Currying. Die analytische und die kategorielle Exponentiation sind nicht dieselbe Konstruktion, aber sie teilen dieselbe DNA: beide verwandeln eine „additive/koprodukt-artige" Struktur in eine „multiplikative/produkt-artige".
#
# 5. Zurück zu deinen Herzthemen
#
# Zum Abschluss die Verbindung, die dich freuen dürfte — sie schlägt den Bogen zu deiner zyklischen Kohomologie. In deinem Dokument taucht in §8 der Kozyklus $\psi(a_0,a_1)=\tfrac{i}{2}\operatorname{Tr}(a_0[H,a_1])$ auf, und in §10 das Heisenberg-Bild $A_t=U_t^\dagger A_0 U_t$. Beides hängt über die Exponentiation zusammen: Die innere Automorphismengruppe
# $$\alpha_t(a)=e^{itH}\,a\,e^{-itH}$$
# ist eine Einparametergruppe, deren *Erzeuger* die Derivation
# $$\delta(a)=\frac{d}{dt}\Big|_{t=0}\alpha_t(a)=i[H,a]$$
# ist. Der Kommutator $[H,-]$ ist also die „Ableitung" der exponentierten Konjugation — die infinitesimale Version dessen, was $e^{itH}$ endlich macht. Und genau solche Derivationen $\delta$ spielen in der nichtkommutativen Geometrie die Rolle der äußeren Ableitung $d$. Die Exponentiation ist somit die Maschine, die deine algebraischen Erzeuger ($[H,-]$, Hochschild-Welt) in geometrische Flüsse (das Heisenberg-Bild, die kovariant/kontravariant-Dualität) integriert.

# %% [markdown]
# ###### <font color="blue">*Kohomologie*

# %% [markdown]
# <font color="blue">**Periodische, zyklischen Kohomologie**
#
# <font color="blue">*Wichtige Zusatznotizen*
#
# * Messung von Veränderungen: Geometrie eine Differentialform = in der Algebra einen Kozyklus
# * die Zyklische Kategorie: Diese Kategorie nimmt die Simplizes und stattet sie mit einer inneren Symmetrie aus – einer Rotation.“ Diese Rotation ist der zyklische Operator τn.
#
# 1. Ausgangslage und konzeptioneller Rahmen
#
# Der klassische Fall ist die glatte Mannigfaltigkeit $M$ mit ihrer **kommutativen** Algebra $A = C^\infty(M)$ der glatten Funktionen. Topologische Invarianten erhält man hier über die **de Rham-Kohomologie** $H^*_{dR}(M)$, also durch Integration von Differentialformen $\omega \in \Omega^n(M)$ über $M$.
#
# Connes' Leitfrage (1981–1985): *Was bleibt, wenn man die Punkte und die Kommutativität verliert?* Sein Geniestreich besteht in der Erkenntnis, dass die algebraische Essenz eines Integrals — eine multilineare Form $\varphi(f_0, df_1, \dots, df_n)$ mit **zyklischer Symmetrie** (via Stokes: $\int d(\dots)=0$) und **graduierter Antisymmetrie** in den $df_i$ — ein autonomes Konzept ist, das *keine* Mannigfaltigkeit voraussetzt. Übrig bleibt eine Kohomologie für jede assoziative Algebra, die im kommutativen, glatten Fall wieder $H^*_{dR}$ liefert. Der konzeptionelle Schritt: **Integration über Mannigfaltigkeit → zyklische Spur auf Algebra**.
#
# 2. De Rham-Kohomologie (das kommutative Referenzobjekt)
#
# **Definition.** Für eine glatte Mannigfaltigkeit $M$ sei $\Omega^k(M)$ der Raum der glatten $k$-Formen. Die äußere Ableitung $d: \Omega^k(M) \to \Omega^{k+1}(M)$ ist lokal definiert durch
#
# $$d\bigl(f\, dx_{i_1}\wedge\dots\wedge dx_{i_k}\bigr) = \sum_j \frac{\partial f}{\partial x_j}\, dx_j \wedge dx_{i_1} \wedge \dots \wedge dx_{i_k},$$
#
# und die Kohomologiegruppen sind
#
# $$H^k_{dR}(M) = \frac{\ker(d:\Omega^k\to\Omega^{k+1})}{\operatorname{im}(d:\Omega^{k-1}\to\Omega^k)}.$$
#
# Das Keilprodukt $\wedge$ ist antikommutativ ($dx\wedge dy = -dy\wedge dx$) und erfüllt die **graduierte Leibniz-Regel** für $\alpha\in\Omega^p, \beta\in\Omega^q$:
#
# $$d(\alpha\wedge\beta) = d\alpha\wedge\beta + (-1)^p \alpha\wedge d\beta.$$
#
# **Rechenbeispiel.** Im $\mathbb{R}^2$ mit $\alpha = x\,dy$, $\beta = y\,dx$:
#
# Direkt: $\alpha\wedge\beta = -xy\,(dx\wedge dy)$, und $d(-xy\,dx\wedge dy)=0$, weil $dx\wedge dx=0$ und $dy\wedge dy=0$.
#
# Via Leibniz ($p=1$): $d\alpha = dx\wedge dy$, $d\beta = -dx\wedge dy$, und
#
# $$d\alpha\wedge\beta - \alpha\wedge d\beta = y(dx\wedge dy\wedge dx) + x(dy\wedge dx\wedge dy) = 0.$$
#
# Beide Wege liefern $0$ — die Struktur ist konsistent.
#
# 3. Hochschild-Komplex (das Fundament)
#
# Sei $A$ eine assoziative, unitale $\mathbb{C}$-Algebra. Der Raum der $n$-Koketten ist
#
# $$C^n(A) := \operatorname{Hom}_{\mathbb{C}}(A^{\otimes(n+1)}, \mathbb{C}),$$
#
# also der Raum aller multilinearen Funktionale $\varphi: A^{n+1}\to\mathbb{C}$. Der **Hochschild-Korandoperator** $b: C^n(A)\to C^{n+1}(A)$ ist
#
# $$(b\varphi)(a_0,\dots,a_{n+1}) = \sum_{i=0}^n (-1)^i \varphi(a_0,\dots,a_i a_{i+1},\dots,a_{n+1}) + (-1)^{n+1}\varphi(a_{n+1}a_0, a_1,\dots,a_n).$$
#
# Es gilt $b^2 = 0$. Die Hochschild-Kohomologie $HH^n(A) := H^n(C^*(A), b)$ ist das nichtkommutative Analogon zu $\Omega^n(M)$.
#
# **Konkret in Grad 0:** Eine 0-Kokette $\varphi: A\to\mathbb{C}$ erfüllt $b\varphi=0$ genau dann, wenn $\varphi(a_0 a_1) = \varphi(a_1 a_0)$ für alle $a_0, a_1\in A$ — das heißt: *Eine 0-Kokokette im Kern von $b$ ist genau eine Spur auf $A$.* Spuren übernehmen in der nichtkommutativen Welt die Rolle der Integration von 0-Formen.
#
# 4. Zyklische Kohomologie via zyklische Symmetrie
#
# Der zyklische Permutationsoperator $\lambda: C^n(A)\to C^n(A)$ ist
#
# $$(\lambda\varphi)(a_0,\dots,a_n) = (-1)^n \varphi(a_n, a_0,\dots,a_{n-1}).$$
#
# Eine Kokette heißt **zyklisch**, falls $\lambda\varphi = \varphi$. Der Unterraum
#
# $$C^n_\lambda(A) := \{\varphi\in C^n(A): \lambda\varphi = \varphi\}$$
#
# ist unter $b$ invariant (Connes' Beobachtung: $b(C^n_\lambda)\subset C^{n+1}_\lambda$). Damit ist $(C^*_\lambda(A), b)$ ein Teilkomplex, und
#
# $$\boxed{\;HC^n(A) := H^n(C^*_\lambda(A), b) = \frac{\ker\bigl(b: C^n_\lambda(A)\to C^{n+1}_\lambda(A)\bigr)}{\operatorname{im}\bigl(b: C^{n-1}_\lambda(A)\to C^n_\lambda(A)\bigr)}\;}$$
#
# ist die **zyklische Kohomologie** von $A$.
#
# 5. Der $(b,B)$-Bikomplex (die rechnerisch mächtige Beschreibung)
#
# Die $\lambda$-Definition ist anschaulich, in der Praxis aber unhandlich — die zyklische Bedingung ist extrem restriktiv, und Quantenalgebren erlauben selten eine explizite Isolierung von $C^n_\lambda$. Connes' zweite Beschreibung umgeht das.
#
# **Der Connes-Korandoperator** $B: C^n(A)\to C^{n-1}(A)$ wird als Komposition definiert:
#
# $$B = N \circ s \circ (1-\lambda), \quad N = \sum_{i=0}^{n-1}\lambda^i \text{ (Norm)}, \quad (s\varphi)(a_0,\dots,a_{n-1}) = \varphi(1, a_0,\dots,a_{n-1}).$$
#
# Explizit:
#
# $$(B\varphi)(a_0,\dots,a_{n-1}) = \sum_{i=0}^{n-1}(-1)^{(n-1)i}\,\varphi(1, a_i,\dots,a_{n-1}, a_0,\dots,a_{i-1}).$$
#
# Es gelten die fundamentalen Identitäten
#
# $$b^2 = 0, \qquad B^2 = 0, \qquad bB + Bb = 0.$$
#
# Damit lebt die zyklische Kohomologie auf einem zweidimensionalen Gitter, dem **$(b,B)$-Bikomplex** mit horizontalem $b$ (Grad +1) und vertikalem $B$ (Grad −1):
#
# $$\begin{array}{ccccc}
# \vdots & & \vdots & & \\
# \uparrow B & & \uparrow B & & \\
# C^2(A) & \xrightarrow{b} & C^3(A) & \xrightarrow{b} & \cdots \\
# \uparrow B & & \uparrow B & & \\
# C^1(A) & \xrightarrow{b} & C^2(A) & \xrightarrow{b} & \cdots \\
# \uparrow B & & \uparrow B & & \\
# C^0(A) & \xrightarrow{b} & C^1(A) & \xrightarrow{b} & \cdots
# \end{array}$$
#
# Die zyklische Kohomologie ist die Kohomologie des Totalkomplexes — äquivalent zur $\lambda$-Definition (**Connes' Theorem**), aber rechnerisch deutlich handhabbarer, weil man im *unrestringierten* Raum $C^n(A)$ arbeitet.
#
# **Rechenbeispiel ($B$ in Aktion, $n=1$).** Für eine 1-Kokette $\varphi\in C^1(A)$ kollabieren die drei Zahnräder ($(1-\lambda)$, $s$, $N$) zu
#
# $$(B\varphi)(a_0) = \varphi(1, a_0) + \varphi(a_0, 1).$$
#
# Sei $A = M_2(\mathbb{C})$ und $\psi(M_1, M_2) = \operatorname{Tr}(M_1 M_2)$. Dann
#
# $$(B\psi)(a_0) = \operatorname{Tr}(I\cdot a_0) + \operatorname{Tr}(a_0\cdot I) = 2\operatorname{Tr}(a_0).$$
#
# $B$ hat aus der 1-Kokette die fundamentale 0-dimensionale Struktur (die Spur) extrahiert.
#
# **Rechenbeispiel ($bB+Bb=0$, kommutativer Fall).** Für $A=\mathbb{C}[x]$ und die 1-Kokette $\phi(f_0,f_1) = f_0(0)f_1'(0)$ ergibt sich $(B\phi)(f_0) = f_0'(0)$, und beide Wege liefern Null: $b(B\phi)(f_0,f_1) = (f_0 f_1)'(0) - (f_1 f_0)'(0) = 0$ (wegen Kommutativität), und $(b\phi)(f_0,f_1,f_2) = 0$ nach Produktregel-Aufrechnung. Also $(bB+Bb)\phi = 0$.
#
# **Warum braucht man $B$ überhaupt?** Drei Gründe: (i) Rechnen in $C^n_\lambda$ ist bei komplexen Algebren praktisch unmöglich; im Bikomplex arbeitet man mit allen Koketten. (ii) $B$ ist das *echte* geometrische Analogon der äußeren Ableitung $d$, während $b$ eine algebraische Assoziativitätsprüfung ist. (iii) Ohne den Bikomplex existiert der Periodizitätsoperator $S$ nicht — und damit keine periodische zyklische Kohomologie und keine Brücke zur K-Theorie.
#
# 6. Die SBI-Sequenz (Connes-Periodizität)
#
# Hochschild- und zyklische Kohomologie hängen über die exakte Sequenz
#
# $$\cdots \to HH^n(A) \xrightarrow{I} HC^n(A) \xrightarrow{S} HC^{n+2}(A) \xrightarrow{B} HH^{n+1}(A) \to \cdots$$
#
# zusammen. Die drei Akteure: $I$ vergisst die zyklische Symmetrie (Hochschild ist „größer"); $S$ ist der **Periodizitätsoperator** und erhöht den Grad um 2 — das Herzstück der ganzen Theorie; $B$ ist der Connes-Korand als verbindender Homomorphismus zurück in die Hochschild-Welt.
#
# 7. Periodische zyklische Kohomologie $HP$
#
# Da $S$ die Dimension stets um 2 erhöht, ist der direkte Limes wohldefiniert:
#
# $$\boxed{\;HP^n(A) := \varinjlim\Bigl(HC^n(A) \xrightarrow{S} HC^{n+2}(A) \xrightarrow{S} HC^{n+4}(A) \xrightarrow{S} \cdots\Bigr).\;}$$
#
# $HP$ ist **2-periodisch**: $HP^n(A) \cong HP^{n+2}(A)$. Es bleiben also nur zwei Gruppen, $HP^{\mathrm{even}}(A)$ und $HP^{\mathrm{odd}}(A)$. Sie sind der natürliche Empfänger des **Chern-Charakters** und das eigentliche Rechenwerkzeug der nichtkommutativen Geometrie: Sie filtern das „Rauschen" der gewöhnlichen $HC^*$ heraus und liefern die puren, robusten topologischen Invarianten von Quantenräumen (z. B. Hall-Leitfähigkeit, topologische Isolatoren).
#
# 8. Interpretation der Ergebnisse: Werkzeugprüfung vs. Messung
#
# Eine wichtige Unterscheidung, die oft Verwirrung stiftet: Es gibt zwei Ebenen, auf denen eine Zahl (Null oder nicht) auftauchen kann.
#
# **Ebene 1 — Werkzeugprüfung ($b\varphi = 0$?):** Hier prüft man, ob $\varphi$ überhaupt ein Kozyklus ist, also als Messgerät zugelassen wird. $b\varphi=0$ bedeutet: gültiger Kozyklus. $b\varphi\neq 0$: nicht zugelassen.
#
# **Ebene 2 — eigentliche Messung ($\varphi(a_0,\dots,a_n)=?$):** Mit einem gültigen Kozyklus $\varphi$ misst man konkrete Tupel. Ergebnis 0 heißt: auf *dieser* Route keine topologische Aktivität. Ergebnis $\neq 0$ heißt: hier ist eine geometrische Verklebung, ein Hindernis, eine umrundete „Achse".
#
# **Quantenbeispiel.** Mit $\psi(a_0, a_1) = \tfrac{i}{2}\operatorname{Tr}(a_0[H, a_1])$ und $H=\sigma_z$: Diese Funktion ist ein zyklischer 1-Kozyklus ($b\psi=0$ automatisch wegen Spureigenschaften). Die Messungen ergeben $\psi(\sigma_x,\sigma_x)=0$ (keine Aktivität), aber $\psi(\sigma_y,\sigma_x)=-2$ — der Hamiltonoperator verklebt die Richtungen $\sigma_x$ und $\sigma_y$ aktiv miteinander (Präzession).
#
# 9. Cup-Produkt und Ringstruktur
#
# In der Homologie kann man Ketten addieren, aber nicht multiplizieren. In der Kohomologie hingegen sind Koketten *Funktionale*, deren Werte sich multiplizieren lassen — das ergibt das **Cup-Produkt** $\smile$. Für $\phi\in C^p(X)$, $\psi\in C^q(X)$ ist $\phi\smile\psi\in C^{p+q}(X)$ definiert durch
#
# $$(\phi\smile\psi)([v_0,\dots,v_{p+q}]) = \phi([v_0,\dots,v_p]) \cdot \psi([v_p,\dots,v_{p+q}]),$$
#
# also „Vorderseite mal Rückseite" des Simplex. Damit wird $H^*(X) = \bigoplus_n H^n(X)$ ein **graduiert kommutativer Ring**:
#
# $$\alpha\smile\beta = (-1)^{pq}(\beta\smile\alpha) \quad \text{für } \alpha\in H^p, \beta\in H^q.$$
#
# **Rechenbeispiel ($\Delta^2$ mit Ecken $v_0, v_1, v_2$).** Setze $\phi(e_{01})=1$ (sonst 0), $\psi(e_{12})=1$ (sonst 0). Dann
#
# $$(\phi\smile\psi)([v_0,v_1,v_2]) = \phi([v_0,v_1])\cdot\psi([v_1,v_2]) = 1\cdot 1 = 1,$$
#
# aber $(\psi\smile\phi)([v_0,v_1,v_2]) = \psi([v_0,v_1])\cdot\phi([v_1,v_2]) = 0\cdot 0 = 0$.
#
# Auf Kokettenebene also nicht kommutativ; erst nach Übergang zu Kohomologieklassen wird das Produkt graduiert kommutativ. Geometrisch misst das Cup-Produkt das *Hintereinanderkleben* von Eigenschaften: erst $\phi$-Bedingung, dann direkt $\psi$-Bedingung.
#
# Im Übergang zu Differentialformen wird $\smile$ zum **Keilprodukt** $\wedge$, und der Korandoperator $\delta$ zum äußeren Differential $d$. Connes' Definition der zyklischen Kohomologie reproduziert im kommutativen, glatten Fall genau diese Struktur.
#
# 10. Kovariant vs. Kontravariant — die Pfeil-Asymmetrie
#
# Sei $\psi: A\to B$ ein Algebrenhomomorphismus.
#
# **Zyklische Homologie $HC_*$ ist kovariant.** Ketten der Form $a_0\otimes\dots\otimes a_n$ lassen sich vorwärts schieben:
#
# $$\psi_*(a_0\otimes\dots\otimes a_n) = \psi(a_0)\otimes\dots\otimes\psi(a_n), \qquad \psi_*: HC_n(A)\to HC_n(B).$$
#
# **Zyklische Kohomologie $HC^*$ ist kontravariant.** Koketten sind Funktionale $\varphi: B^{n+1}\to\mathbb{C}$, und der induzierte Pfeil läuft *rückwärts*:
#
# $$(\psi^*\varphi)(a_0,\dots,a_n) = \varphi(\psi(a_0),\dots,\psi(a_n)), \qquad \psi^*: HC^n(B)\to HC^n(A).$$
#
# **Warum die Asymmetrie?** Die Komposition zwingt die Richtung. Aus $C_n(X)\xrightarrow{f_*} C_n(Y)\xrightarrow{\varphi}\mathbb{Z}$ entsteht eine Kokette auf $X$, nicht auf $Y$. Da der Zielraum eines Funktionals starr der Skalarkörper ist, kann der Pfeil am Ende nicht umgebogen werden — Funktionale (Messgeräte) lassen sich nur *zurückziehen* (Pullback), nicht vorwärtsschieben.
#
# **Rechenbeispiel.** Sei $\psi: \mathbb{C}[x]\to\mathbb{C}$, $\psi(p) = p(0)$ (Auswertung am Ursprung). Ein lineares Funktional $\varphi(z) = cz$ auf $\mathbb{C}$ wird zu
#
# $$(\psi^*\varphi)(p) = \varphi(\psi(p)) = c\cdot p(0).$$
#
# Aus einem Messgerät auf dem Ziel $B = \mathbb{C}$ ist ein Messgerät auf dem Ursprung $A = \mathbb{C}[x]$ geworden — der Pfeil wurde umgedreht.
#
# **Quanten-Brückenschlag.** Diese Dualität ist exakt der Unterschied zwischen Schrödinger- und Heisenberg-Bild. Schrödinger ist kovariant ($\rho_t = U_t\rho_0 U_t^\dagger$, Zustände werden vorwärts geschoben). Heisenberg ist kontravariant ($A_t = U_t^\dagger A_0 U_t$, Observablen werden zurückgezogen — daher das adjungierte $U_t^\dagger$ vorne, das genauso auftaucht wie bei kontravarianten Tensoren in der ART).
#
# 11. HKR-Theorem als Brücke
#
# Das **Hochschild-Kostant-Rosenberg-Theorem** schlägt die Brücke zurück zum klassischen Fall: Für glatte kommutative Algebren $A = C^\infty(M)$ gilt
#
# $$HH_n(A) \cong \Omega^n(M),$$
#
# und die zyklische Kohomologie reproduziert in diesem Fall die de Rham-Kohomologie. Connes' Definition ist also so geschnitten, dass sie im kommutativen, glatten Fall die klassische Theorie *exakt* zurückgewinnt — bleibt aber starr genug, um auf wilden, nichtkommutativen Quantenalgebren sinnvolle topologische Aussagen zu treffen.
#
# 12. Quick Reference — die Bausteine auf einen Blick
#
# - $A^{\otimes(n+1)}$ — Tensorprodukt; eine Kokette frisst $n+1$ Algebraelemente als getrennte Argumente.
# - $C^n(A)$ — $n$-Koketten: multilineare Funktionale $A^{n+1}\to\mathbb{C}$.
# - $b: C^n\to C^{n+1}$ — Hochschild-Korand; hebt den Grad.
# - $\lambda$ — zyklischer Permutator; bewegt das letzte Argument nach vorn mit Vorzeichen $(-1)^n$.
# - $C^n_\lambda$ — Unterraum der zyklisch invarianten Koketten.
# - $B: C^n\to C^{n-1}$ — Connes-Korand; senkt den Grad, geometrisches Analogon zu $d$.
# - $S: HC^n\to HC^{n+2}$ — Periodizitätsoperator; Schlüssel zur 2-Periodizität.
# - $I$ — Inklusion $HH^n\hookrightarrow HC^n$ (vergisst zyklische Symmetrie).
# - $HH^n(A)$ — Hochschild, analog zu $\Omega^n(M)$.
# - $HC^n(A)$ — zyklische Kohomologie, analog zu $H^n_{dR}(M)$ im kommutativen Fall.
# - $HP^{\mathrm{even/odd}}(A)$ — periodische zyklische Kohomologie, Empfänger des Chern-Charakters.
#
#
# <font color="blue">*Rechenbeispiel: $A = M_n(\mathbb{C})$*
#
# * **$A = M_n(\mathbb{C})$** (wo die Spur als Urgenerator aller zyklischen Klassen erscheint). dann $A = M_n(\mathbb{C})$, in dem die **Spur als Urbild aller zyklischen Kozyklen** sichtbar wird.
# * $A = M_n(\mathbb{C})$ - Dieses Beispiel ist viel reicher, weil hier die **Spur** als fundamentale zyklische Klasse explizit erscheint.
# 1. Setup: Sei $A = M_n(\mathbb{C})$ die Algebra der $n \times n$-Matrizen. Wir suchen einen Erzeuger von $HC^0(A)$.
#   * **Definition:** $\;\tau_0 \in C^0(A)$ via $\tau_0(A) := \mathrm{Tr}(A)$ (die Matrix-Spur).
# 2. Verifikation: $\tau_0$ ist Hochschild-Kozyklus
#   * Wir rechnen: $(b\tau_0)(A_0, A_1) = \tau_0(A_0 A_1) - \tau_0(A_1 A_0) = \mathrm{Tr}(A_0 A_1) - \mathrm{Tr}(A_1 A_0).$
#   * Die **fundamentale Spureigenschaft** $\mathrm{Tr}(XY) = \mathrm{Tr}(YX)$ liefert sofort $b\tau_0 = 0. \qquad \checkmark$
#   * Beobachten Sie: Die Hochschild-Kozyklus-Bedingung für Grad $0$ ist *genau* die Spur-Eigenschaft. Daher gilt allgemein $HC^0(A) = HH^0(A) = \{\text{stetige Spuren auf } A\}.$
# 3. Verifikation: $\tau_0$ ist zyklisch invariant
#   * Für $n = 0$ ist die zyklische Bedingung $(\lambda\tau_0)(A_0) = (-1)^0 \tau_0(A_0) = \tau_0(A_0)$, also automatisch erfüllt. Damit $[\tau_0] \in HC^0(M_n(\mathbb{C})).$
# 4. Eindeutigkeit: Bestimmung von $HC^0$
#   * Da $M_n(\mathbb{C})$ einfach ist und jede Spur ein Vielfaches der Standardspur ist: $HC^0(M_n(\mathbb{C})) = \mathbb{C} \cdot [\tau_0] \cong \mathbb{C}.$
# 5. **Konstruktion höhergradiger zyklischer Kozyklen**
#  * Hier kommt die *Periodizität* konkret zum Tragen. Wir definieren für jedes $k \geq 0$: $\tau_{2k}(A_0, A_1, \dots, A_{2k}) := \mathrm{Tr}(A_0 A_1 \cdots A_{2k}).$
# * **Schritt A: Hochschild-Kozyklus**
# $$(b\tau_{2k})(A_0,\dots,A_{2k+1}) = \sum_{i=0}^{2k} (-1)^i \,\mathrm{Tr}(A_0 \cdots A_i A_{i+1} \cdots A_{2k+1}) \;+\; (-1)^{2k+1}\, \mathrm{Tr}(A_{2k+1} A_0 \cdots A_{2k}).$$
#
# * Beobachtung 1: In jedem Innenterm bleibt das Produkt $A_0 A_1 \cdots A_{2k+1}$ unverändert (Assoziativität).
# Beobachtung 2: Der letzte Term liefert via Spur-Zyklizität $\mathrm{Tr}(A_{2k+1} A_0 \cdots A_{2k}) = \mathrm{Tr}(A_0 \cdots A_{2k+1})$.
#
# * Damit
# $$(b\tau_{2k})(A_0,\dots,A_{2k+1}) = \mathrm{Tr}(A_0 \cdots A_{2k+1}) \cdot \underbrace{\left[\sum_{i=0}^{2k}(-1)^i + (-1)^{2k+1}\right]}_{= 1 + (-1) = 0} = 0. \qquad \checkmark$$
#
# * **Schritt B: Zyklische Invarianz**
# $$(\lambda\tau_{2k})(A_0,\dots,A_{2k}) = (-1)^{2k}\,\mathrm{Tr}(A_{2k} A_0 A_1 \cdots A_{2k-1}) = \mathrm{Tr}(A_0 \cdots A_{2k}) = \tau_{2k}(A_0,\dots,A_{2k}). \qquad \checkmark$$
#
# * (Hier nutzt man wieder Spur-Zyklizität.)
#
# * **Folgerung**:
# $$[\tau_{2k}] \in HC^{2k}(M_n(\mathbb{C})), \qquad k = 0, 1, 2, \dots$$
#
# * Diese Klassen werden durch den Periodizitäts-Operator $S$ aufeinander abgebildet:
# $$S[\tau_{2k}] = [\tau_{2k+2}] \quad \text{(bis auf nicht-verschwindenden Vorfaktor)}.$$
#
# 6. Morita-Invarianz und der Schluss
#
# * Es gilt das **Morita-Theorem für zyklische Kohomologie**:
# $$HC^*(M_n(A)) \cong HC^*(A) \quad \text{für jede Algebra } A.$$
# * Mit $A = \mathbb{C}$ folgt $HC^*(M_n(\mathbb{C})) = HC^*(\mathbb{C}) = (\mathbb{C}, 0)$-periodisch — und wir haben gerade explizit den Erzeuger in jedem Grad konstruiert.
# * Die explizite Isomorphie wird durch die *verallgemeinerte Spur* realisiert: für $\varphi \in C^*(\mathbb{C})$ sei
# $$\Phi(A_0, A_1, \dots, A_n) := \varphi(1, \dots, 1) \cdot \mathrm{Tr}(A_0 A_1 \cdots A_n).$$
# * Das ist die Hauptpointe von Morita-Invarianz in der zyklischen Welt: **die Spur ist die universelle Verbindung zwischen $\mathbb{C}$ und $M_n(\mathbb{C})$**.

# %% [markdown]
# ###### <font color="blue">*Tensor Algebra*

# %% [markdown]
# <font color="blue">**Tensor Calculus**
#
# * **Geodesics (Geodäten):**
# Eine Geodäte ist die geradeste Kurve in einem gekrümmten Raum, entlang derer der eigene Tangentialvektor parallel transportiert wird, sodass ihre intrinsische Beschleunigung verschwindet.
# In curved space, a straight path has zero tangential acceleration when we travel along it at constant speed.
#
# $$\frac{d^2 x^i}{d\lambda^2} + \Gamma^i_{jk} \frac{dx^j}{d\lambda} \frac{dx^k}{d\lambda} = 0$$
#
# * Extrinsic: To compute geodesic curves, we need to find curves where the acceleration vector is normal to the surface.
#
# $$\frac{d^2 \vec{R}}{d \lambda^2}=\left(\frac{d^2 \vec{R}}{d \lambda^2}\right)^{\text {normal }}+\underbrace{\left(\frac{d^2 \vec{R}}{d \lambda^2}\right)^{\text {tangential }}}_{=0}$$
#
#
# * **Christoffelsymbole:**
# Diese koordinatenabhängigen, nicht-tensoriellen Größen kodieren präzise, wie sich die lokalen Basisvektoren von Punkt zu Punkt auf der Mannigfaltigkeit verbiegen.
#
# $$\Gamma^k_{ij} = \frac{1}{2} g^{kl} (\partial_i g_{jl} + \partial_j g_{il} - \partial_l g_{ij})$$
#
#
# * **Parallel Transport (Paralleltransport):** ist eine Vorschrift, die bestimmt, wie ein Vektor entlang einer Kurve verschoben wird, sodass er im geometrischen Sinne "konstant" bleibt und die lokale Krümmung der Koordinaten exakt ausgleicht.
#
# $$\nabla_{\dot{\gamma}} V = 0 \iff \frac{dV^i}{d\lambda} + \Gamma^i_{jk} V^j \frac{dx^k}{d\lambda} = 0$$
#
#
# * **Lie-Klammer (Lie Bracket):**
# Sie misst die Nicht-Kommutativität zweier Vektorfelder $X$ und $Y$, also gewissermaßen die infinitesimale "Lücke", die entsteht, wenn man die Flüsse der beiden Felder in unterschiedlicher Reihenfolge durchläuft.
#
# $$[X, Y]^i = X^j \partial_j Y^i - Y^j \partial_j X^i$$
#
#
# * **Connection / Levi-Civita Connection (Zusammenhang):**
# Ein affiner Zusammenhang ermöglicht die richtungsabhängige (kovariante) Ableitung von Tensorfeldern; der Levi-Civita-Zusammenhang ist der eindeutige Zusammenhang, der sowohl torsionsfrei ist als auch die Metrik respektiert (die Längen und Winkel bei Paralleltransport erhält).
#
# $$\nabla_Z g = 0 \quad \text{und} \quad \nabla_X Y - \nabla_Y X = [X,Y]$$
#
#
# * **Torsion Tensor:**
# Dieser Tensor fängt den asymmetrischen Teil des Zusammenhangs ein und gibt geometrisch an, inwiefern sich infinitesimale Parallelogramme, die durch den Paralleltransport gebildet werden, nicht schließen.
#
# $$T^k_{ij} = \Gamma^k_{ij} - \Gamma^k_{ji}$$
#
#
# * **Holonomie:** beschreibt die globale Diskrepanz – oft eine Drehung –, die ein Vektor erfährt, nachdem er auf einer gekrümmten Mannigfaltigkeit parallel entlang einer vollständig geschlossenen Schleife transportiert wurde.
#
# $$\text{Hol}(\gamma) = \mathcal{P} \exp \left( \oint_\gamma \Gamma_\mu dx^\mu \right)$$
#
#
# * **Riemann Curvature Tensor (Riemannscher Krümmungstensor):**
# Dieses ultimative "(1,3)-Tensor-Monster" quantifiziert intrinsisch die Krümmung des Raumes, indem er die Nicht-Kommutativität der zweiten kovarianten Ableitungen misst.
#
# $$R^l_{\ ijk} = \partial_j \Gamma^l_{ik} - \partial_k \Gamma^l_{ij} + \Gamma^l_{jm} \Gamma^m_{ik} - \Gamma^l_{km} \Gamma^m_{ij}$$
#
#
# * **Ricci-Tensor & Ricci-Skalar:**
# Der Ricci-Tensor entsteht durch Spur-Bildung (Kontraktion) des Riemann-Tensors und misst die Volumenänderung eines geodätischen Balls; eine weitere Kontraktion liefert den Ricci-Skalar, eine einzige Zahl pro Punkt, die die totale Skalarkrümmung angibt.
#
# $$R_{ij} = R^k_{\ ikj} \quad \text{und} \quad R = g^{ij} R_{ij}$$
#
#
# * **Bianchi-Identität:**
# Diese differentiellen Identitäten sind die geometrischen Entsprechungen der Erhaltungssätze (wie Energie und Impuls) und diktieren, wie sich die Krümmung von Punkt zu Punkt stetig und konsistent verhalten muss.
#
# $$\nabla_l R^i_{\ jkm} + \nabla_k R^i_{\ jml} + \nabla_m R^i_{\ jlk} = 0$$
#
#
# * **Schnittkrümmung (Sectional Curvature):**
# Sie liefert eine anschauliche zweidimensionale Krümmungsmaßzahl (vergleichbar mit der Gaußschen Krümmung), die angibt, wie stark eine durch zwei Tangentialvektoren $X$ und $Y$ aufgespannte "Ebene" gekrümmt ist.
#
# $$K(X,Y) = \frac{\langle R(X,Y)Y, X \rangle}{\langle X,X \rangle \langle Y,Y \rangle - \langle X,Y \rangle^2}$$

# %% [markdown]
# <font color="blue">**Tensor Algebra**
#
#
# * **Tangentialraum $T_pM$:** ein Punkt $p$ auf Mannigfaltigkeit und untersuchen die Vektorräume, die an diesem Punkt "kleben".
#   * Vektoren (Derivationen) und Kovektoren (1-Formen) koordinatenfreie, abstrakte Objekte
# * **Vektoren als Derivationen** (kontravariant) als Richtungsableitungen einer Funktion, zB: $\vec{e_x} = \frac{\delta}{ \delta_x}$
#   * Vector: $\vec{v} = v^i \vec{e}_i = \widetilde{v}^i \vec{\widetilde{e}}_i$
#   * **Basis Vectors / Covariant (1,0-Tensor)**: $\vec{\widetilde{e}}_j = F_j^i \vec{e}_i \qquad \vec{e}_j = B_j^i \vec{\widetilde{e}}_i$
#   * **Vector components / Contravariant (0,1-Tensor)**: $\widetilde{v}^i = B_j^i v^j \qquad v^i = F_j^i \widetilde{v}^j$
# * **Kovektoren als Differentialformen** (kovariant) als "Schichten", die von Vektoren durchstoßen werden
#   * Kovector: $\alpha = \alpha_i \epsilon^i = \widetilde{\alpha}_i \widetilde{\epsilon}^i$
#   * **Basis Covectors / Contravariant (0,1-Tensor)**: $\widetilde{\epsilon}^i = B_j^i \epsilon^j \qquad \epsilon^i = F_j^i \widetilde{\epsilon}^j$
#   * **Covector Components / Covariant (1,0-Tensor)**: $\widetilde{\alpha}_j = F_j^i \alpha_i \qquad \alpha_j = B_j^i \widetilde{\alpha}_i$
# * **Vector fields** mit Basiswechsel (Funktor) und Jacobimatrix
#   * Vector: $\vec{e}_1 \longleftrightarrow \frac{\partial}{\partial x} \qquad \vec{e}_2 \longleftrightarrow \frac{\partial}{\partial y}$ (derivatives)
#   * Vector Fields (Kettenregel für Tangentialvektoren): $\frac{d}{d\lambda} = \frac{dc^i}{d\lambda} \frac{\partial}{\partial c^i} = \frac{dp^i}{d\lambda} \frac{\partial}{\partial p^i}$
#   * Basis Vectors / Covariant: $\frac{\partial}{\partial p^j} = \frac{\partial c^i}{\partial p^j} \frac{\partial}{\partial c^i} \qquad \frac{\partial}{\partial c^j} = \frac{\partial p^i}{\partial c^j} \frac{\partial}{\partial p^i}$
#   * Vector Components / Contravariant: $\frac{dp^i}{d\lambda} = \frac{\partial p^i}{\partial c^j} \frac{dc^j}{d\lambda} \qquad \frac{dc^i}{d\lambda} = \frac{\partial c^i}{\partial p^j} \frac{dp^j}{d\lambda}$
# * **Covector fields** mit Basiswechsel (Funktor) und Jacobimatrix
#   * Covector: $\epsilon^1 \longleftrightarrow dx \qquad \epsilon^2 \longleftrightarrow dy$ (differentials)
#   * Covector Fields (Totales Differential einer Funktion): $df = \frac{\partial f}{\partial c^i} dc^i = \frac{\partial f}{\partial p^i} dp^i$
#   * Basis Covectors / Contravariant: $dp^i = \frac{\partial p^i}{\partial c^j} dc^j \qquad dc^i = \frac{\partial c^i}{\partial p^j} dp^j$
# * **Gradient vs. die äußere Ableitung (Exterior Derivative):** der Gradient benötigt eine Metrik, das äußere Differential $d$ auf Differentialformen aber eine rein topologische Operation ist.
#   * 'functions vector fields' -> differential forms vs. 'grad curl div' -> exterior derivative. **Integration with Differential Forms**:
#   * **$∇ f$ - Del operator, gradient**. A gradient gives a **vector field** with pointing to steepest increase (acts on scalar field) - Covariant Derivative $\nabla$ und affine Connection (gewöhnliche partielle Ableitung die Tensoreigenschaft zerstört und wie wir sie reparieren.)
#   * **$d f$ Dee operator, differential, exterior derivative of $f$** - differential forms = gives us a **covector field**. Easier, it doesn't depend on coordinate systems at all!
# * **Metrik Tensor (Bilinearform):**
#   * (0,2)-Tensor. Instrument zur Messung von Abständen und Winkeln, Indezes ziehen. Index Raising and Lowering: The most powerful feature of the metric tensor is its ability to convert covariant indices into contravariant ones, and vice versa (musikalische Isomorphismus)
#   * $\widetilde{g}_{ij} = F^k_i F^l_j g_{kl}$
#   * $g_{kl} = B^i_k B^j_l \widetilde{g}_{ij}$
#   * **Metric Tensor:** covariant $g_{i,j}$ from $V$ with $\vec{v}$ to $V^*$, lives in $V^* \otimes V^*$.   * *Convert from vector to covector with metric tensor:*
#     * $\vec{v} = v^j \vec{e}_j = \widetilde{v}^j \widetilde{\vec{e}}_j$ (vector)
#     * $\vec{v} \cdot \_ = v_i \epsilon^i = \widetilde{v}_i \widetilde{\epsilon}^i$ (covector)
#     * $v_i = g_{ij} v^j$ bzw. $\widetilde{v}_i = \widetilde{g}_{ij} \widetilde{v}^j$
#     * $v_i = g_{ij} v^j$ bzw. $\widetilde{v}_i = \widetilde{g}_{ij} \widetilde{v}^j$
#     * Metric Tensor for Curved Surfaces:
#   $\left[\begin{array}{cc}\frac{d \vec{R}}{d u} \cdot \frac{d \vec{R}}{d u} & \frac{d \vec{R}}{d u} \cdot \frac{d \vec{R}}{d v} \\ \frac{d \vec{R}}{d v} \cdot \frac{d \vec{R}}{d u} & \frac{d \vec{R}}{d v} \cdot \frac{d \vec{R}}{d v}\end{array}\right]$ bzw. als Vector: $\left[\begin{array}{ll}\overrightarrow{e_u} \cdot \overrightarrow{e_u} & \overrightarrow{e_u} \cdot \overrightarrow{e_v} \\ \overrightarrow{e_v} \cdot \overrightarrow{e_u} & \overrightarrow{e_v} \cdot \overrightarrow{e_v}\end{array}\right]$
#     * Sandwich Metric tensor between covector and vector: $g(\vec{v}, \vec{w})=v^i w^j g_{i j}$ = $=\left[\begin{array}{ll}v^1 & v^2\end{array}\right]\left[\begin{array}{ll}g_{11} & g_{12} \\ g_{21} & g_{22}\end{array}\right]\left[\begin{array}{l}w^1 \\ w^2\end{array}\right]$
#     * Anwendung in u, v: $\left\|\frac{d \vec{R}}{d \lambda}\right\|^2=\frac{d \vec{R}}{d \lambda} \cdot \frac{d \vec{R}}{d \lambda}$ $=\left[\begin{array}{ll}\frac{d u}{d \lambda} & \frac{d v}{d \lambda}\end{array}\right]\left[\begin{array}{ll}\frac{d \vec{R}}{d u} \cdot \frac{d \vec{R}}{d u} & \frac{d \vec{R}}{d u} \cdot \frac{d \vec{R}}{d v} \\ \frac{d \vec{R}}{d v} \cdot \frac{d \vec{R}}{d u} & \frac{d \vec{R}}{d v} \cdot \frac{d \vec{R}}{d v}\end{array}\right]\left[\begin{array}{l}\frac{d u}{d \lambda} \\ \frac{d v}{d \lambda}\end{array}\right]$
#     * Anwendung in X, Y, Z: $\left\|\frac{d \vec{R}}{d \lambda}\right\|^2=\frac{d \vec{R}}{d \lambda} \cdot \frac{d \vec{R}}{d \lambda}$ = $\left[\begin{array}{lll}\frac{d X}{d \lambda} & \frac{d Y}{d \lambda} & \frac{d Z}{d \lambda}\end{array}\right]\left[\begin{array}{lll}\frac{\partial \vec{R}}{\partial X} \cdot \frac{\partial \vec{R}}{\partial X} & \frac{\partial \vec{R}}{\partial X} \cdot \frac{\partial \vec{R}}{\partial Y} & \frac{\partial \vec{R}}{\partial X} \cdot \frac{\partial \vec{R}}{\partial Z} \\ \frac{\partial \vec{R}}{\partial Y} \cdot \frac{\partial \vec{R}}{\partial X} & \frac{\partial \vec{R}}{\partial Y} \cdot \frac{\partial \vec{R}}{\partial Y} & \frac{\partial \vec{R}}{\partial Y} \cdot \frac{\partial \vec{R}}{\partial Z} \\ \frac{\partial \vec{R}}{\partial Z} \cdot \frac{\partial \vec{R}}{\partial X} & \frac{\partial \vec{R}}{\partial Z} \cdot \frac{\partial \vec{R}}{\partial Y} & \frac{\partial \vec{R}}{\partial Z} \cdot \frac{\partial \vec{R}}{\partial Z}\end{array}\right]\left[\begin{array}{l}\frac{d X}{d \lambda} \\ \frac{d Y}{d \lambda} \\ \frac{d Z}{d \lambda}\end{array}\right]$
#   * **Inverse Metric Tensor:** contravariant $\mathfrak{g_{i,j}}$, lives in $V \otimes V$
#   * **Metric tensor and invers metric tensor with $∇ f$ (gradient, vector) and $d f$ (differential, covector):**
#     * Use metric tensor $g = (\nabla f)^i g_{i j}=\frac{\partial f}{\partial c^j}$ to go from vector field **$∇ f$ (gradient)** to covector field **$d f$ (differential, exterior derivative of $f$)**.
#     * Use inverse metric tensor $\mathfrak{g}$ = $(\nabla f)^k= \mathfrak{g}^{j k} \frac{\partial f}{\partial c^j}$ to go from covector field **$d f$ (differential, exterior derivative of $f$)** back to vector field **$∇ f$ (gradient)** .
#   * **Kronecker delta** when both combined: $\mathfrak{g}^{k i} \otimes g_{i j}=\delta_j^k$
#   * **(m,n)- Tensor** Transformation rule
#     * Definition der Indizes: $T^{ijk\dots \quad  → \text{ contravariant indexes}}_{rst\dots \quad  → \text{ covariant indexes}}$
#     * Transformation zu den neuen Indizes: $\widetilde{T}^{abc\dots}_{xyz\dots} = (B^a_i B^b_j B^c_k \dots) T^{ijk\dots}_{rst\dots} (F^r_x F^s_y F^t_z \dots)$
#     * Transformation zu den alten Indizes: $T^{ijk\dots}_{rst\dots} = (F^i_a F^j_b F^k_c \dots) \widetilde{T}^{abc\dots}_{xyz\dots} (B^x_r B^y_s B^z_t \dots)$
#   * **Lowering an index:** $v_i = g_{ij} v^j$ which is the $\flat$ operator (from vector arrow to flat covector stack)
#   * **Raising an index:** $v^i = g^{ij} v_j$ which is the $\sharp$ operator (from covector $\alpha$ to vector $\vec{a}$
#   * (Note: The contravariant metric tensor $g^{ij}$ is the matrix inverse of the covariant tensor $g_{ij}$).
# * (1,1)-Tensor
#   * $\widetilde{L}^i_j = B^i_k L^k_l F^l_j$
#   * $L^i_j = F^i_k \widetilde{L}^k_l B^l_j$

# %% [markdown]
# <font color="blue">**Tensor Algebra**
#
# 1. Multilineare Abbildung
# * Bilinearformen, das euklidische Skalarprodukt. Es nimmt zwei Vektoren aus dem kartesischen Produkt und macht eine Zahl daraus: $B(a, b) = a \cdot b \in \mathbb{R}$. Das ist eine Funktion, noch keine Algebra von Elementen.
#
# 2. Tensoralgebra $T(V)$:
# * bilden das Tensorprodukt $a \otimes b$. Dies ist weder ein Skalar noch ein reiner Flächeninhalt. Es ist eine Dyade, ein $3 \times 3$-Matrix-artiges Objekt, das als linearer Operator fungieren kann. Es codiert sowohl den Teil, der parallel ist, als auch den, der senkrecht steht. Hier ist alles erlaubt, nichts wird vereinfacht. Ein Tensor 2. Stufe $v \otimes w$ ist einfach nur ein abstraktes Paar.
# * Warum haben wir das Tensorprodukt $V \otimes W$ überhaupt erfunden? Um multilineare Abbildungen in gewöhnliche *lineare* Abbildungen zu verwandeln! In der Kategorientheorie gibt es einen wunderbaren Isomorphismus. Die Menge aller bilinearen Abbildungen $B: V \times V \to \mathbb{R}$ ist isomorph zur Menge der rein linearen Abbildungen $L: V \otimes V \to \mathbb{R}$. Das bedeutet: Jede Bilinearform ist streng genommen ein Funktional auf dem Tensorprodukt! Das Tensorprodukt wurde exakt dafür konstruiert, die multilineare Algebra zu algebraisieren.
#
# 3. Äußeren Algebra $\Lambda(V)$:
# * rein topologisch. Wir bilden das Keilprodukt $a \wedge b$. Das innere Produkt (die Längen-Information) wird hier rigoros vernichtet. Es bleibt *nur* der reine **Bivektor**, der das orientierte Parallelogramm beschreibt, das $a$ und $b$ aufspannen. $a \wedge a = 0$. Wir nehmen die Tensoralgebra und erzwingen die Regel $v \otimes v = 0$. Dadurch entsteht das **Keilprodukt** ($\wedge$). Hier werden abstrakte Bivektoren ($v \wedge w$) geboren. Sie sind antisymmetrische Tensoren. Diese Algebra hat keine Metrik, sie beschreibt nur Volumina und Schnittpunkte.
#
# 4. Geometrischen Algebra $Cl(V, q)$:
# * geometrisch/metrisch. Wir bilden das geometrische Produkt $ab$. Hier fügt sich alles zusammen! Die Geometrische Algebra nimmt die Bilinearform (1) und den abstrakten Bivektor aus der Äußeren Algebra (3) und summiert sie auf: $ab = B(a,b) + (a \wedge b)$. Das Ergebnis ist ein "Multivektor", der gleichzeitig einen Skalarteil und einen Bivektorteil besitzt.  Wir nehmen wieder die Tensoralgebra, erzwingen aber eine andere Regel: $v \otimes v = q(v)$ (die Länge des Vektors).
# * **Bivektoren und Keilprodukte in der Geometrischen Algebra**: Weil die Geometrische Algebra als Vektorraum *isomorph* (strukturgleich) zur Äußeren Algebra ist! Wenn wir in der Geometrischen Algebra zwei Vektoren multiplizieren, spaltet sich das Produkt auf: $vw = \underbrace{v \cdot w}_{\text{Skalar}} + \underbrace{v \wedge w}_{\text{Bivektor}}$. Die Geometrische Algebra "klaut" sich also den Bivektor aus der Äußeren Algebra (der klassischen multilinearen Algebra) und kombiniert ihn mit dem inneren Produkt. Das **geometrische Produkt** zweier Vektoren zerfällt in einen *symmetrischen* (Bilinearform) und einen *antisymmetrischen* (äußeres Produkt) Anteil: $ab \;=\; \underbrace{\tfrac12(ab+ba)}_{=\,a\cdot b\;=\;g(a,b)} \;+\; \underbrace{\tfrac12(ab-ba)}_{=\,a\wedge b}.$
# * Damit vereinigt die geometrische Algebra **Bilinearform** und **äußere Algebra** in einem einzigen, assoziativen, *invertierbaren* Produkt. Skalarprodukt (Metrik) und Keilprodukt (Fläche) sind keine getrennten Operationen mehr, sondern zwei Gradkomponenten desselben Produkts.
# * **Konkretes Beispiel ($\mathbb{R}^3$, euklidisch).** Orthonormalbasis $e_1,e_2,e_3$ mit $q(e_i)=1$: $e_1 e_1 = e_1\cdot e_1 = 1, \qquad e_1 e_2 = e_1\wedge e_2 \;(\text{denn } e_1\cdot e_2 = 0).$ Das Bivektor $e_1\wedge e_2$ ist (per Hodge-Dualität) der „Achse" $e_3$ dual — so reproduziert die geometrische Algebra das **Kreuzprodukt** als Schatten des Keilprodukts. Mit $q=0$ verschwände der erste Term, $e_ie_i=0$, und man hätte nur noch die nackte äußere Algebra.
#
# 5. Verbindung zu zyklischer Kohomologie
# * Die äußere Ableitung $d:\Omega^k(M)\to\Omega^{k+1}(M)$ macht aus den Differentialformen den **de Rham-Komplex**, dessen Kohomologie $H^*_{dR}(M)$ in Ihrem Dokument das *kommutative Referenzobjekt* ist. Connes' Programm abstrahiert genau diese Kette: Die multilineare Form $\varphi(f_0, df_1,\dots,df_n)$ — ein Funktional, das die äußere-Algebra-Struktur der $df_i$ benutzt — wird zum zyklischen Kozyklus. Und das **HKR-Theorem** schließt die Schleife formal: $HH_n\bigl(C^\infty(M)\bigr) \;\cong\; \Omega^n(M) = \Gamma(\Lambda^n T^*M).$
# * Die Hochschild-Homologie *gewinnt die äußeren Potenzen zurück*. Der gesamte Turm — Multilinearität $\to$ Tensoralgebra $\to$ äußere Algebra $\to$ Differentialformen $\to$ de Rham — ist also präzise das, was die zyklische Kohomologie auf nichtkommutative „Quantenalgebren" verallgemeinert, wo es keine Punkte und kein $T_pM$ mehr gibt.
#
# 6. Differentialgeometrie
# * = Tensor Analysis + Differentialformen in gekrümmten Räumen
# * Jetzt wird das lokale Gerüst über eine glatte Mannigfaltigkeit $M$ gespannt. In jedem Punkt $p$ ist $T_pM$ ein Vektorraum — und man wendet **faserweise** genau die obige Algebra an:
# - **Bilinearform $\to$ Metrik.** Eine glatt variierende symmetrische Bilinearform $g_p$ auf $T_pM$ ist die Riemannsche Metrik, ein Schnitt von $S^2T^*M$: $g = \sum_{i,j} g_{ij}\, dx^i\otimes dx^j, \qquad g_{ij}=g_{ji}.$
# - **Äußere Algebra $\to$ Differentialformen.** Die $k$-Formen sind die Schnitte des äußeren Bündels: $\Omega^k(M) = \Gamma\bigl(\Lambda^k T^*M\bigr).$
# Das $\wedge$ in $\omega = f\, dx\wedge dy$ ist *wörtlich* das Produkt der äußeren Algebra, faserweise — inklusive $dx\wedge dy = -dy\wedge dx$.
# - **Tensoralgebra $\to$ Tensorfelder**; **Clifford-Bündel $\to$ Spinoren, Dirac-Operator.**
# * **Tangentialbündel, Faser, Bündel, Schnitt** als grundlegende Begriffe
# * Eine Metrik (symmetrisches 2-Tensorfeld) und eine 2-Form (antisymmetrisches 2-Tensorfeld) leben beide in $T^*M\otimes T^*M$ — die symmetrische bzw. äußere Quotientenbildung trennt sie. *Dieselbe* Dichotomie wie auf der vertikalen Achse, nur jetzt geometrisch

# %% [markdown]
# ###### <font color="blue">*Lie Algebra*

# %% [markdown]
# <font color="blue">**Lie Algebra**
#
# Lie-Gruppen und Lie-Algebren — eine Übersicht
#
# Ich freue mich über diese Frage, denn sie führt ins Herz dessen, was man die *Infinitesimalisierung von Symmetrie* nennen könnte. Es ist eine der schönsten Brücken der Mathematik: Sie verbindet eine **gekrümmte, nichtlineare** Welt (die Gruppe, eine Mannigfaltigkeit) mit einer **flachen, linearen** Welt (die Algebra, ein Vektorraum) — und das Werkzeug, das beide verklebt, ist die Exponentialabbildung. Lassen Sie uns das sauber von Grund auf aufbauen.
#
# 1. Die Leitidee
#
# Eine **Lie-Gruppe** ist eine Symmetrie, die man *kontinuierlich* variieren kann: Drehungen, Verschiebungen, Lorentz-Transformationen. Anders als bei endlichen Gruppen kann man hier von einem Element „ein bisschen" zum nächsten gehen — die Gruppe ist eine glatte Mannigfaltigkeit.
#
# Der entscheidende Trick: Eine solche gekrümmte Mannigfaltigkeit ist global schwer zu fassen, aber sie sieht **am neutralen Element $e$** lokal wie ein flacher Vektorraum aus — der Tangentialraum. Dieser Tangentialraum, ausgestattet mit einer einzigen zusätzlichen Operation (der *Lie-Klammer*), ist die **Lie-Algebra**. Sie ist die „linearisierte Gruppe", die Sammlung aller *infinitesimalen Symmetrien*.
#
# Das Bemerkenswerte ist: Diese lineare Schattenstruktur enthält fast die *gesamte* Information der Gruppe. Man kann von der Algebra zur Gruppe zurückkehren — durch Exponentiation.
#
# 2. Die Lie-Gruppe
#
# **Definition.** Eine *Lie-Gruppe* ist eine glatte Mannigfaltigkeit $G$, die zugleich eine Gruppe ist, sodass die beiden Strukturabbildungen glatt sind:
# $$
# \mu: G\times G \to G,\quad (g,h)\mapsto gh \qquad\text{und}\qquad \iota: G\to G,\quad g\mapsto g^{-1}.
# $$
#
# Die Dimension der Gruppe ist die Dimension der Mannigfaltigkeit.
#
# **Beispiele.**
#
# - $(\mathbb{R}^n, +)$ — die einfachste, abelsche, flache Lie-Gruppe.
# - $S^1 = U(1) = \{e^{i\theta}\}$ — der Kreis, Dimension $1$, kompakt.
# - $GL(n,\mathbb{R})$ — die invertierbaren Matrizen, eine offene Teilmenge von $M_n(\mathbb{R})\cong\mathbb{R}^{n^2}$, Dimension $n^2$.
# - $SL(n)$, $O(n)$, $SO(n)$, $U(n)$, $SU(n)$, $Sp(2n)$ — die *klassischen Gruppen*, definiert durch algebraische Bedingungen wie $\det = 1$ oder $A^\dagger A = I$.
#
# Diese Bedingungen schneiden Untermannigfaltigkeiten aus $GL(n)$ heraus; deshalb spricht man von *Matrix-Lie-Gruppen*. Praktisch jede Lie-Gruppe, die einem begegnet, lässt sich als Matrixgruppe realisieren.
#
# 3. Die Lie-Algebra
#
# **Intuition.** Stellen Sie sich vor, Sie stehen am neutralen Element $e\in G$ und fragen: *In welche Richtungen kann ich infinitesimal losgehen?* Die Antwort ist der Tangentialraum $T_eG$. Jede solche Richtung ist eine „Geschwindigkeit", mit der eine Symmetrie startet — etwa „beginne zu drehen um die $z$-Achse".
#
# **Definition (geometrisch).** Die Lie-Algebra ist
# $$
# \mathfrak{g} := T_eG,
# $$
# der Tangentialraum am neutralen Element. Für eine Matrixgruppe sind das genau die Geschwindigkeitsvektoren $\gamma'(0)$ von glatten Kurven $\gamma(t)\in G$ mit $\gamma(0)=I$.
#
# **Die Lie-Klammer.** Was $\mathfrak{g}$ von einem bloßen Vektorraum unterscheidet, ist eine bilineare, antisymmetrische Operation $[\,\cdot\,,\cdot\,]:\mathfrak{g}\times\mathfrak{g}\to\mathfrak{g}$. Für Matrixgruppen ist sie der **Kommutator**:
# $$
# [X,Y] = XY - YX.
# $$
#
# Sie misst, *wie stark die Gruppe nicht kommutativ ist*. Das sieht man am sogenannten Gruppenkommutator $g h g^{-1}h^{-1}$: Setzt man $g=e^{tX}$, $h=e^{sY}$ ein und entwickelt, so heben sich alle Terme erster Ordnung weg, und der führende Korrekturterm ist
# $$
# e^{tX}e^{sY}e^{-tX}e^{-sY} = \exp\bigl(ts\,[X,Y] + \text{höhere Ordnung}\bigr).
# $$
# Die Klammer ist also die *infinitesimale Nichtkommutativität* der Gruppe — exakt analog dazu, wie in Ihrem Quantenbeispiel zur zyklischen Kohomologie der Kommutator $[H,a]$ die „aktive Verklebung" von Richtungen misst.
#
# **Definition (abstrakt).** Eine *Lie-Algebra* ist ein Vektorraum $\mathfrak{g}$ mit einer bilinearen Abbildung $[\,\cdot\,,\cdot\,]$, die
# $$
# [X,X]=0 \quad(\text{Antisymmetrie}) \qquad\text{und}\qquad
# \underbrace{[X,[Y,Z]]+[Y,[Z,X]]+[Z,[X,Y]]=0}_{\text{Jacobi-Identität}}
# $$
# erfüllt. Die Jacobi-Identität ist nichts anderes als die infinitesimale Version der Assoziativität der Gruppe.
#
# **Strukturkonstanten.** Wählt man eine Basis $e_1,\dots,e_d$ von $\mathfrak{g}$, so ist die gesamte Algebra durch Zahlen $c_{ij}^k$ kodiert:
# $$
# [e_i,e_j]=\sum_k c_{ij}^k\, e_k.
# $$
#
# **Beispiele.**
#
# - $\mathfrak{gl}(n)=M_n(\mathbb{C})$ — *alle* Matrizen, Klammer $=$ Kommutator. (Genau die Algebra $M_n(\mathbb{C})$, die in Ihrem Dokument als Heimat der Spur auftaucht!)
# - $\mathfrak{sl}(n) = \{X : \operatorname{Tr}X = 0\}$ — die spurlosen Matrizen, Lie-Algebra von $SL(n)$.
# - $\mathfrak{so}(n) = \{X : X^\top = -X\}$ — die antisymmetrischen Matrizen.
# - $\mathfrak{su}(n) = \{X : X^\dagger = -X,\ \operatorname{Tr}X = 0\}$ — spurlose anti-hermitesche Matrizen.
#
# Beachten Sie das Muster: Die Gruppenbedingung „$\det = 1$" wird zur Algebrabedingung „$\operatorname{Tr} = 0$"; „$A^\top A = I$" wird zu „$X^\top + X = 0$". Das ist kein Zufall — es ist die abgeleitete (linearisierte) Form der Bedingung, wie wir gleich sehen.
#
# 4. Die Exponentialabbildung — die Brücke $\mathfrak{g}\to G$
#
# Hier geschieht die Magie. Gegeben eine infinitesimale Symmetrie $X\in\mathfrak{g}$ (eine Anfangsgeschwindigkeit), wie erzeugt man daraus eine *endliche* Symmetrie in $G$? Antwort: Man „integriert die Geschwindigkeit auf".
#
# **Definition.** Die *Einparameter-Untergruppe* zu $X\in\mathfrak{g}$ ist die eindeutige Kurve $\gamma_X:\mathbb{R}\to G$ mit
# $$
# \gamma_X(0)=e,\qquad \gamma_X'(0)=X,\qquad \gamma_X(s+t)=\gamma_X(s)\gamma_X(t).
# $$
# Die **Exponentialabbildung** ist dann
# $$
# \exp:\mathfrak{g}\to G,\qquad \exp(X):=\gamma_X(1).
# $$
#
# **Für Matrixgruppen** ist das wörtlich die Matrix-Exponentialreihe:
# $$
# \boxed{\;\exp(X)=\sum_{k=0}^\infty \frac{X^k}{k!} = I + X + \tfrac{1}{2}X^2 + \tfrac{1}{6}X^3 + \cdots\;}
# $$
# und $\gamma_X(t)=\exp(tX)$.
#
# **Eigenschaften, die man kennen sollte:**
#
# 1. $\exp$ bildet eine Umgebung von $0\in\mathfrak{g}$ **diffeomorph** auf eine Umgebung von $e\in G$ ab. Das Differential im Ursprung ist die Identität: $d(\exp)_0 = \mathrm{id}_{\mathfrak{g}}$.
# 2. $\exp((s{+}t)X)=\exp(sX)\exp(tX)$ — aber **Vorsicht:** im Allgemeinen ist $\exp(X)\exp(Y)\neq\exp(X+Y)$, sobald $[X,Y]\neq 0$! (Das korrigiert die BCH-Formel, gleich.)
# 3. Determinantenformel: $\det(\exp X)=e^{\operatorname{Tr}X}$. Daher gilt $X\in\mathfrak{sl}(n)\Leftrightarrow \operatorname{Tr}X=0\Leftrightarrow \det(\exp X)=1$. *So* hängen die Bedingungen auf Gruppen- und Algebraebene zusammen.
# 4. Surjektivität ist nicht selbstverständlich. Für **kompakte zusammenhängende** Lie-Gruppen ist $\exp$ surjektiv. Für $SL(2,\mathbb{R})$ dagegen *nicht* — es gibt Gruppenelemente, die in keinem Bild der Exponentialabbildung liegen.
#
# 5. Der Logarithmus und die Baker–Campbell–Hausdorff-Formel
#
# Da $\exp$ lokal ein Diffeomorphismus ist, existiert nahe $e$ eine **lokale Umkehrung**, der Logarithmus $\log:U\subset G\to\mathfrak{g}$. Für Matrizen nahe $I$:
# $$
# \log(I+N)=\sum_{k=1}^\infty \frac{(-1)^{k+1}}{k}\,N^k = N - \tfrac{1}{2}N^2 + \tfrac{1}{3}N^3 - \cdots.
# $$
#
# Die zentrale Frage lautet nun: Wenn $\exp(X)\exp(Y)$ wieder ein Element nahe $e$ ist, *welches* Element der Algebra ergibt sich beim Zurücklogarithmieren? Die Antwort ist eine der tiefsten Formeln der Theorie:
#
# **Baker–Campbell–Hausdorff (BCH).**
# $$
# \boxed{\;\log\bigl(e^X e^Y\bigr) = X+Y+\tfrac{1}{2}[X,Y]+\tfrac{1}{12}\bigl([X,[X,Y]]+[Y,[Y,X]]\bigr)-\tfrac{1}{24}[Y,[X,[X,Y]]]+\cdots\;}
# $$
#
# Das ist konzeptionell spektakulär: **Die gesamte Gruppenmultiplikation lässt sich (lokal) allein durch wiederholte Lie-Klammern ausdrücken.** Die Gruppe verrät kein neues Geheimnis jenseits dessen, was die Algebra mit ihrer Klammer schon weiß. Im abelschen Fall ($[X,Y]=0$) kollabiert alles zu $\log(e^Xe^Y)=X+Y$, und $\exp$ ist ein echter Homomorphismus.
#
# 6. Die adjungierte Darstellung — wie $\mathrm{ad}$ aus der Klammer entsteht
#
# Die Gruppe wirkt auf sich selbst durch Konjugation, $h\mapsto ghg^{-1}$. Linearisiert man diese Wirkung an $e$, erhält man die **adjungierte Darstellung** der Gruppe auf ihrer Algebra:
# $$
# \mathrm{Ad}_g:\mathfrak{g}\to\mathfrak{g},\qquad \mathrm{Ad}_g(X)=gXg^{-1}\quad(\text{für Matrizen}).
# $$
#
# Differenziert man *auch dies* noch einmal — nun nach $g=\exp(tX)$ bei $t=0$ —, erhält man die adjungierte Darstellung der **Algebra**:
# $$
# \mathrm{ad}_X:\mathfrak{g}\to\mathfrak{g},\qquad \mathrm{ad}_X(Y)=[X,Y].
# $$
#
# Die beiden hängen — wie sollte es anders sein — über die Exponentialabbildung zusammen:
# $$
# \mathrm{Ad}_{\exp X} = \exp(\mathrm{ad}_X).
# $$
# Die Jacobi-Identität ist übrigens äquivalent dazu, dass $\mathrm{ad}$ ein Lie-Algebra-Homomorphismus ist: $\mathrm{ad}_{[X,Y]}=[\mathrm{ad}_X,\mathrm{ad}_Y]$. Alles fügt sich zu einem konsistenten Turm aus Ableitungen.
#
# 7. Die Lie-Korrespondenz
#
# Das große Strukturresultat (Lie, Cartan):
#
# > Die Zuordnung $G\mapsto\mathfrak{g}$, $(\phi:G\to H)\mapsto(d\phi_e:\mathfrak{g}\to\mathfrak{h})$ ist ein **Funktor**, der eine Äquivalenz zwischen der Kategorie der *einfach zusammenhängenden* Lie-Gruppen und der Kategorie der *endlichdimensionalen* reellen Lie-Algebren stiftet.
#
# Drei Bemerkungen, die das einordnen:
#
# - **Lokal bestimmt $\mathfrak{g}$ die Gruppe vollständig** (via BCH). Global jedoch nicht: Verschiedene Gruppen können dieselbe Algebra haben, wenn sie sich in Topologie (Fundamentalgruppe, Zusammenhang) unterscheiden.
# - Das Paradebeispiel: $\mathfrak{su}(2)\cong\mathfrak{so}(3)$ als Lie-Algebren, aber $SU(2)\cong S^3$ ist einfach zusammenhängend, während $SO(3)\cong\mathbb{RP}^3$ es nicht ist. $SU(2)$ ist die **universelle Überlagerung** und überlagert $SO(3)$ doppelt ($\pm I\mapsto I$). Das ist die mathematische Wurzel des Spin-$\tfrac{1}{2}$.
# - **Lies dritter Satz:** Jede endlichdimensionale reelle Lie-Algebra ist tatsächlich die Algebra *einer* Lie-Gruppe.
#
# Da Sie Kategorientheorie schätzen: Hier haben Sie einen lehrbuchreifen Funktor mitsamt seinen Limitierungen — er ist *nicht* voll treu auf allen Lie-Gruppen, sondern erst nach Einschränkung auf die einfach zusammenhängenden. Das „Vergessen der Topologie" ist genau der Informationsverlust.
#
# 8. Konkrete Beispiele, durchgerechnet
#
# **(a) $SO(2)$ — der Kreis, abelsch.** Die Algebra besteht aus den antisymmetrischen $2\times 2$-Matrizen:
# $$
# X=\begin{pmatrix}0&-\theta\\\theta&0\end{pmatrix}.
# $$
# Wegen $X^2=-\theta^2 I$ separiert die Exponentialreihe in $\cos$ und $\sin$:
# $$
# \exp(X)=\begin{pmatrix}\cos\theta&-\sin\theta\\\sin\theta&\cos\theta\end{pmatrix}.
# $$
# Da die Gruppe abelsch ist, ist BCH trivial und $\exp$ ein globaler Homomorphismus $\mathbb{R}\to S^1$.
#
# **(b) $SO(3)$ — Drehungen, das nichtabelsche Grundbeispiel.** Eine Basis von $\mathfrak{so}(3)$ sind die drei Erzeuger
# $$
# L_x=\begin{pmatrix}0&0&0\\0&0&-1\\0&1&0\end{pmatrix},\quad
# L_y=\begin{pmatrix}0&0&1\\0&0&0\\-1&0&0\end{pmatrix},\quad
# L_z=\begin{pmatrix}0&-1&0\\1&0&0\\0&0&0\end{pmatrix},
# $$
# mit den Relationen $[L_x,L_y]=L_z$, $[L_y,L_z]=L_x$, $[L_z,L_x]=L_y$. Hier sind die Strukturkonstanten gerade der Levi-Civita-Tensor: $c_{ij}^k=\varepsilon_{ijk}$. Die Exponentiation einer Drehachse $K=\hat n\cdot\vec L$ liefert die **Rodrigues-Formel**:
# $$
# \exp(\theta K)=I+\sin\theta\,K+(1-\cos\theta)\,K^2.
# $$
#
# **(c) $SU(2)$ — Spinoren.** Hier ist $\mathfrak{su}(2)$ aufgespannt von $-\tfrac{i}{2}\sigma_k$ mit den Pauli-Matrizen $\sigma_x,\sigma_y,\sigma_z$. Für eine Drehachse $\hat n$ gilt wegen $(\hat n\cdot\vec\sigma)^2=I$ die elegante Formel
# $$
# \exp\!\Bigl(-\tfrac{i\theta}{2}\,\hat n\cdot\vec\sigma\Bigr)=\cos\tfrac{\theta}{2}\,I-i\sin\tfrac{\theta}{2}\,(\hat n\cdot\vec\sigma).
# $$
# Der Faktor $\theta/2$ statt $\theta$ ist die Signatur der Doppelüberlagerung: Erst bei $\theta=4\pi$ kehrt man zur Identität zurück, nicht bei $2\pi$.
#
# 9. Brücke zu Ihren Lieblingsthemen
#
# Da Sie geometrische Algebra lieben, ein Bonbon: In der Clifford-/geometrischen Algebra bilden die **Rotoren** $R=e^{B/2}$ (mit einem Bivektor $B$) die Gruppe $\mathrm{Spin}(n)$, und die **Bivektoren** bilden ihre Lie-Algebra. Das ist nicht bloß analog zu $SU(2)$ — es *ist* dieselbe Struktur in koordinatenfreier Sprache: $\mathrm{Spin}(3)\cong SU(2)$, und ein Bivektor exponentiert genau wie oben zu einem Rotor. Die geometrische Algebra liefert damit das vielleicht intuitivste Bild des Exponentialgesetzes überhaupt: *Bivektor = infinitesimale Drehebene, Rotor = endliche Drehung*.
#
# Und zur zyklischen Kohomologie Ihres Dokuments: Es gibt eine direkte Schwester der hier beschriebenen Theorie, die **Lie-Algebra-Kohomologie** (Chevalley–Eilenberg). Dort spielt die Klammer $[\,\cdot\,,\cdot\,]$ exakt die Rolle, die das äußere Differential $d$ in de Rham bzw. der Connes-Korand $B$ in der zyklischen Welt spielt — der Korandoperator $d_{CE}$ ist buchstäblich aus den Strukturkonstanten gebaut. Wenn Sie mögen, können wir das als Nächstes erkunden; es schließt den Kreis zu Ihrem Hauptthema sehr schön.
#
# 10. Quick Reference
#
# | Objekt | Symbol | Bedeutung |
# |---|---|---|
# | Lie-Gruppe | $G$ | glatte Mannigfaltigkeit + Gruppe |
# | Lie-Algebra | $\mathfrak{g}=T_eG$ | Tangentialraum an $e$, infinitesimale Symmetrien |
# | Lie-Klammer | $[X,Y]=XY-YX$ | infinitesimale Nichtkommutativität |
# | Jacobi-Identität | $\sum_{\text{zykl}}[X,[Y,Z]]=0$ | infinitesimale Assoziativität |
# | Exponential | $\exp:\mathfrak{g}\to G$ | $\mathfrak{g}\rightsquigarrow G$, lokaler Diffeo. |
# | Logarithmus | $\log:G\to\mathfrak{g}$ | lokale Umkehrung nahe $e$ |
# | BCH | $\log(e^Xe^Y)=X{+}Y{+}\tfrac12[X,Y]{+}\dots$ | Multiplikation aus Klammern |
# | Adjungiert (Gruppe) | $\mathrm{Ad}_g(X)=gXg^{-1}$ | Konjugationswirkung |
# | Adjungiert (Algebra) | $\mathrm{ad}_X(Y)=[X,Y]$ | $\mathrm{Ad}_{\exp X}=\exp(\mathrm{ad}_X)$ |
#
# Möchten Sie, dass ich an einer bestimmten Stelle tiefer einsteige — etwa die BCH-Formel über die adjungierte Wirkung herleite, die Doppelüberlagerung $SU(2)\to SO(3)$ explizit ausrechne, oder die Brücke zur Lie-Algebra-Kohomologie und damit zurück zu Ihrer zyklischen Welt schlage?
#
# ---
#
# [Video](https://youtu.be/csolG83gCV8?is=-nefmmN0ui90_S0d)
#
# 1. Intuitive Texterklärung
#
# Die grundlegende Motivation der Lie-Theorie (im Kontext der Robotik) ist der rigorose Umgang mit Transformationen wie Rotationen und Translationen im Raum [[00:36](http://www.youtube.com/watch?v=csolG83gCV8&t=36)]. Diese Operationen bilden mathematische Gruppen, die topologisch betrachtet jedoch als gekrümmte Oberflächen (sogenannte glatte Mannigfaltigkeiten) auftreten [[28:08](http://www.youtube.com/watch?v=csolG83gCV8&t=1688)].
#
# Weil diese Räume gekrümmt sind, funktioniert die klassische lineare Algebra (wie das einfache Addieren von Vektoren oder das Berechnen von Ableitungen) dort nicht direkt. Die Lie-Theorie löst dieses Problem auf elegante Weise durch die Verknüpfung zweier Welten:
#
# * **Die Lie-Gruppe:** Der eigentliche, gekrümmte Raum der Transformationen (z. B. die Kugeloberfläche der 3D-Rotationen).
# * **Die Lie-Algebra:** Der flache Tangentialraum, der exakt am neutralen Element (der Identität) der Gruppe anliegt [[32:18](http://www.youtube.com/watch?v=csolG83gCV8&t=1938)].
#
# Stell dir vor, du legst ein flaches Blatt Papier exakt an den Nordpol einer Kugel. Du kannst auf dem flachen Papier wunderbar einfache lineare Berechnungen durchführen (Geschwindigkeiten extrapolieren, Unsicherheiten messen) und das Ergebnis am Ende wieder entlang der Krümmung "auf die Kugel aufwickeln" [[34:03](http://www.youtube.com/watch?v=csolG83gCV8&t=2043)]. Das ist die Kernphilosophie!
#
# 2. Formale Definition & Formeln
#
# Solà verwendet eine exzellente "Mikro-Notation", um die schwerfällige Differentialgeometrie in der Praxis wie normale Vektorrechnung aussehen zu lassen.
#
# * **Die Lie-Gruppe $G$:** Eine Menge, die die vier Gruppenaxiome erfüllt und zugleich eine glatte (kantenfreie) Mannigfaltigkeit ist [[28:32](http://www.youtube.com/watch?v=csolG83gCV8&t=1712)].
# * **Die Lie-Algebra $\mathfrak{g}$:** Der Tangentialraum an der Identität, formal notiert als $T_e G$ [[36:30](http://www.youtube.com/watch?v=csolG83gCV8&t=2190)]. Ein kartesischer Parametervektor $\tau \in \mathbb{R}^n$ wird durch den sogenannten "Hat"-Operator $(\cdot)^\wedge$ auf ein abstraktes Element der Lie-Algebra abgebildet:
#
# $$\tau^\wedge \in \mathfrak{g}$$
#
#
#
# Die Umkehroperation (von der Matrix zum Vektor) ist der "Vee"-Operator $(\cdot)^\vee$ [[01:04:38](http://www.youtube.com/watch?v=csolG83gCV8&t=3878)].
# * **Exponential- und Logarithmusabbildung:** Die Exponentialabbildung verbindet die Algebra mit der Gruppe. Geometrisch wickelt sie den Vektor auf die Mannigfaltigkeit (entlang einer Geodäten) ab [[47:59](http://www.youtube.com/watch?v=csolG83gCV8&t=2879)]. Formal ist es $\exp: \mathfrak{g} \to G$:
#
# $$X = \exp(\tau^\wedge)$$
#
#
#
# Die inverse Operation, die uns von der Kurve zurück in den flachen Raum bringt, ist die Logarithmusabbildung $\log: G \to \mathfrak{g}$.
# * **Der Plus- und Minus-Operator ($\oplus$ und $\ominus$):** Dies ist Solàs Geniestreich für den angewandten Praktiker. Anstatt ständig abstrakte Lie-Klammern und Exponentialabbildungen zu schreiben, definiert er Abkürzungen [[01:06:05](http://www.youtube.com/watch?v=csolG83gCV8&t=3965)]:
#
# $$X \oplus \tau := X \cdot \exp(\tau^\wedge)$$
#
#
#
# *(Dies addiert eine kleine Vektor-Störung $\tau$ zum aktuellen Zustand $X$.)*
#
# $$\tau := Y \ominus X = \log(X^{-1}Y)^\vee$$
#
#
#
# *(Dies berechnet die vektorielle Differenz zweier Gruppen-Zustände im Tangentialraum [[01:10:31](http://www.youtube.com/watch?v=csolG83gCV8&t=4231)].)*
# * **Die Adjunkt-Matrix ($\operatorname{Ad}_X$):** Da Lie-Gruppen meist nichtkommutativ sind (Drehreihenfolge in 3D ändert das Ergebnis), führt eine Rechtsmultiplikation zu einem anderen Zustand als eine Linksmultiplikation. Die Adjunkt-Matrix schiebt einen Tangentialvektor formal korrekt "durch" das Gruppenelement hindurch [[01:12:09](http://www.youtube.com/watch?v=csolG83gCV8&t=4329)]:
#
# $$X \cdot \exp(\tau^\wedge) = \exp((\operatorname{Ad}_X \tau)^\wedge) \cdot X$$
#
#
# * **Lie-Ableitung (Jacobimatrizen):** Mit $\oplus$ und $\ominus$ lässt sich nun die Ableitung einer Funktion $f: G \to H$ exakt so wie im Newton'schen Kalkül definieren [[01:15:33](http://www.youtube.com/watch?v=csolG83gCV8&t=4533)]:
#
# $$J = \lim_{\tau \to 0} \frac{f(X \oplus \tau) \ominus f(X)}{\tau}$$
#
#
# 3. Konkrete Beispiele
#
# Um das abstrakte Theorie-Gebilde zu verankern, schauen wir uns an, wie man die Lie-Algebra formal aus dem Gruppen-Constraint ableitet.
#
# **Beispiel A: 2D-Rotationen (Komplexe Zahlen $\mathbb{S}^1$)**
#
# * **Die Gruppe:** $G = \{z \in \mathbb{C} \mid z^*z = 1\}$ [[04:07](http://www.youtube.com/watch?v=csolG83gCV8&t=247)].
# * **Herleitung der Lie-Algebra:** Leiten wir die Zwangsbedingung ($z^*z = 1$) nach der Zeit ab, erhalten wir $(z^* z)' = 0 \implies z^*\dot{z} = - (z^*\dot{z})^*$. Eine komplexe Zahl, die gleich ihrem negativen Konjugat ist, muss rein imaginär sein [[39:11](http://www.youtube.com/watch?v=csolG83gCV8&t=2351)].
# * **Die Lie-Algebra:** Ist also die Menge der Vektoren der Form $i\omega$ (mit $\omega \in \mathbb{R}$) [[40:41](http://www.youtube.com/watch?v=csolG83gCV8&t=2441)].
# * **Exponentialabbildung:** Die Taylorreihe von $\exp(i\theta)$ konvergiert exakt zu Eulers Formel: $\exp(i\theta) = \cos(\theta) + i\sin(\theta)$ [[51:33](http://www.youtube.com/watch?v=csolG83gCV8&t=3093)].
#
# **Beispiel B: 3D-Rotationen ($\operatorname{SO}(3)$)**
#
# * **Die Gruppe:** Rotationsmatrizen mit $R^T R = I$ (und positiver Determinante) [[43:06](http://www.youtube.com/watch?v=csolG83gCV8&t=2586)].
# * **Herleitung der Lie-Algebra:** Nach Zeit-Ableitung von $R^T R = I$ erhalten wir $R^T \dot{R} = -(R^T \dot{R})^T$. Das entsprechende Element muss hier also eine schiefsymmetrische (skew-symmetric) $3 \times 3$ Matrix sein [[44:43](http://www.youtube.com/watch?v=csolG83gCV8&t=2683)].
# * **Der "Hat"-Operator:** Nimmt einen kartesischen 3D-Rotationsvektor $\omega = (\omega_x, \omega_y, \omega_z)^T \in \mathbb{R}^3$ und macht daraus die schiefsymmetrische Matrix $\omega^\times \in \mathfrak{so}(3)$ [[45:56](http://www.youtube.com/watch?v=csolG83gCV8&t=2756)].
